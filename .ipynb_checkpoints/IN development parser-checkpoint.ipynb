# %%
# The following file shows the development process of parsing and what we tried in order to make 'Final Parser' file

# %%
import xml.etree.ElementTree as ET

class Task:
    def __init__(self, id, name, incoming, outgoing):
        self.id = id
        self.name = name
        self.incoming = incoming
        self.outgoing = outgoing

class Gateway:
    def __init__(self, id, name, incoming, outgoing):
        self.id = id
        self.name = name
        self.incoming = incoming
        self.outgoing = outgoing

class StartEvent:
    def __init__(self, id, name, incoming, outgoing):
        self.id = id
        self.name = name
        self.incoming = incoming
        self.outgoing = outgoing

class EndEvent:
    def __init__(self, id, name, incoming, outgoing):
        self.id = id
        self.name = name
        self.incoming = incoming
        self.outgoing = outgoing

def parse_bpmn(file_path):
    tree = ET.parse(file_path)
    root = tree.getroot()

    tasks = []
    gateways = []
    start_events = []
    end_events = []

    # Namespace dictionary for finding elements with namespaces
    ns = {'bpmn': 'http://www.omg.org/spec/BPMN/20100524/MODEL'}

    # Parse tasks
    for element in root.findall('.//bpmn:task', ns):
        id = element.attrib.get('id')
        name = element.attrib.get('name', '')
        if name == '':
            created_name = 'Task'+f'{len(gateways)}'
            name = f'{created_name}'
        incoming = [e.text for e in element.findall('bpmn:incoming', ns)]
        outgoing = [e.text for e in element.findall('bpmn:outgoing', ns)]
        task = Task(id, name, incoming, outgoing)
        tasks.append(task)

    # Parse gateways
    for element in root.findall('.//bpmn:exclusiveGateway', ns):
        id = element.attrib.get('id')
        name = element.attrib.get('name', '')
        if name == '':
            created_name = 'ExclusiveGateway'+f'{len(gateways)}'
            name = f'{created_name}'
        incoming = [e.text for e in element.findall('bpmn:incoming', ns)]
        outgoing = [e.text for e in element.findall('bpmn:outgoing', ns)]
        gateway = Gateway(id, name, incoming, outgoing)
        gateways.append(gateway)
        
    for element in root.findall('.//bpmn:eventBasedGateway', ns):
        id = element.attrib.get('id')
        name = element.attrib.get('name', '')
        if name == '':
            created_name = 'EventBasedGateway'+f'{len(gateways)}'
            name = f'{created_name}'
        incoming = [e.text for e in element.findall('bpmn:incoming', ns)]
        outgoing = [e.text for e in element.findall('bpmn:outgoing', ns)]
        gateway = Gateway(id, name, incoming, outgoing)
        gateways.append(gateway)
        
    for element in root.findall('.//bpmn:inclusiveGateway', ns):
        id = element.attrib.get('id')
        name = element.attrib.get('name', '')
        if name == '':
            created_name = 'InclusivedGateway'+f'{len(gateways)}'
            name = f'{created_name}'
        incoming = [e.text for e in element.findall('bpmn:incoming', ns)]
        outgoing = [e.text for e in element.findall('bpmn:outgoing', ns)]
        gateway = Gateway(id, name, incoming, outgoing)
        gateways.append(gateway)
        
    for element in root.findall('.//bpmn:parallelGateway', ns):
        id = element.attrib.get('id')
        name = element.attrib.get('name', '')
        if name == '':
            created_name = 'ParallelGateway'+f'{len(gateways)}'
            name = f'{created_name}'
        incoming = [e.text for e in element.findall('bpmn:incoming', ns)]
        outgoing = [e.text for e in element.findall('bpmn:outgoing', ns)]
        gateway = Gateway(id, name, incoming, outgoing)
        gateways.append(gateway)
        
    for element in root.findall('.//bpmn:intermediateCatchEvent', ns):
        id = element.attrib.get('id')
        name = element.attrib.get('name', '')
        if name == '':
            created_name = 'IntermediateCatchEvent'+f'{len(gateways)}'
            name = f'{created_name}'
        incoming = [e.text for e in element.findall('bpmn:incoming', ns)]
        outgoing = [e.text for e in element.findall('bpmn:outgoing', ns)]
        gateway = Gateway(id, name, incoming, outgoing)
        gateways.append(gateway)

    # Parse start events
    for element in root.findall('.//bpmn:startEvent', ns):
        id = element.attrib.get('id')
        name = element.attrib.get('name', '')
        if name == '':
            created_name = 'StartEvent'+f'{len(gateways)}'
            name = f'{created_name}'
        incoming = [e.text for e in element.findall('bpmn:incoming', ns)]
        outgoing = [e.text for e in element.findall('bpmn:outgoing', ns)]
        start_event = StartEvent(id, name, incoming, outgoing)
        start_events.append(start_event)

    # Parse end events
    for element in root.findall('.//bpmn:endEvent', ns):
        id = element.attrib.get('id')
        name = element.attrib.get('name', '')
        if name == '':
            created_name = 'EndEvent'+f'{len(gateways)}'
            name = f'{created_name}'
        incoming = [e.text for e in element.findall('bpmn:incoming', ns)]
        outgoing = [e.text for e in element.findall('bpmn:outgoing', ns)]
        end_event = EndEvent(id, name, incoming, outgoing)
        end_events.append(end_event)

    return tasks, gateways, start_events, end_events

# Example usage
file_path = 'uebung2_a5605713f817474d99a198ad61d52387_translated.bpmn'
tasks, gateways, start_events, end_events = parse_bpmn(file_path)

# Print parsed objects for verification
print("Tasks:")
for task in tasks:
    print(vars(task))

print("\nGateways:")
for gateway in gateways:
    print(vars(gateway))

print("\nStart Events:")
for start_event in start_events:
    print(vars(start_event))

print("\nEnd Events:")
for end_event in end_events:
    print(vars(end_event))
# Out:
# Tasks:
# {'id': 'sid-80F8D90D-AF83-498D-8975-7F963C3A034F', 'name': 'Check the case', 'incoming': ['sid-3EB6D2A0-5780-4971-9A9A-A07F749C50E6'], 'outgoing': ['sid-720CE06F-A890-4478-81E6-F5D046418D9F']}
# {'id': 'sid-19B4518E-0889-43C1-89A8-DF4978C5DDE6', 'name': 'Send a message', 'incoming': ['sid-FEF249BB-BB19-47DC-B8CE-360B992D1DD5'], 'outgoing': ['sid-4206F21E-F500-4220-83E5-2F8897C662AE']}
# {'id': 'sid-AA1D2C9A-F895-4C91-8FF4-272116373921', 'name': 'Set process for resubmission', 'incoming': ['sid-4206F21E-F500-4220-83E5-2F8897C662AE'], 'outgoing': ['sid-D04063E0-9F9D-492E-A1A2-94ED68FCE6AD']}
# {'id': 'sid-B8696516-0D74-4F6F-AE20-2269402BFB15', 'name': 'Book payment receipt', 'incoming': ['sid-2730F1E2-B1AC-4017-AC5A-6550D850891F'], 'outgoing': ['sid-F47678AB-7384-4EAA-A9C6-1F7EF69A80ED']}
# {'id': 'sid-352C9B2D-2CAC-45A2-9A12-5F784CB3F938', 'name': 'Proceedings', 'incoming': ['sid-7744950A-E48E-4F7E-B3CE-4BF3617828A9'], 'outgoing': ['sid-C21B1B70-6AE7-4234-9AEA-DB6D474598F9']}
# {'id': 'sid-425A8206-DF0B-4D1C-80EE-C4098F3A70CE', 'name': 'Debt collection service provider', 'incoming': ['sid-50EC6540-D291-4F33-840C-3296C898AC3C'], 'outgoing': ['sid-1D98E34C-97AA-4800-86AE-11E3F2E21B56']}
# {'id': 'sid-39FF2FBE-9F9A-44FE-BFDE-AE8F1C2D7607', 'name': 'Close', 'incoming': ['sid-01C86089-2B4B-4E21-95F4-13E72C202A8F'], 'outgoing': ['sid-F5C52874-91ED-4090-9D86-1F2035478864']}
#
# Gateways:
# {'id': 'sid-E2391874-2CA6-47F1-9FE2-B9874D0BE466', 'name': 'Regress?', 'incoming': ['sid-720CE06F-A890-4478-81E6-F5D046418D9F'], 'outgoing': ['sid-FEF249BB-BB19-47DC-B8CE-360B992D1DD5', 'sid-A4983864-7946-4BB1-8002-45D44D73ABC0']}
# {'id': 'sid-41B9B899-451C-486D-9016-CD8449D89E61', 'name': 'Objection?', 'incoming': ['sid-C21B1B70-6AE7-4234-9AEA-DB6D474598F9'], 'outgoing': ['sid-4ED4C473-E7BF-45EE-9049-687F18DAF4E4', 'sid-BA08FF45-5AAE-4DF8-948A-0BB8E6A58AD6']}
# {'id': 'sid-718E7B02-459D-4ADD-8E07-DC8F06DDD148', 'name': 'ExclusiveGateway2', 'incoming': ['sid-8DA11120-2F83-4FBC-B0A9-2551BF21B442', 'sid-4ED4C473-E7BF-45EE-9049-687F18DAF4E4'], 'outgoing': ['sid-50EC6540-D291-4F33-840C-3296C898AC3C']}
# {'id': 'sid-CED26085-A538-48D8-B7F7-71E626B265BD', 'name': 'ExclusiveGateway3', 'incoming': ['sid-A4983864-7946-4BB1-8002-45D44D73ABC0', 'sid-F47678AB-7384-4EAA-A9C6-1F7EF69A80ED', 'sid-1D98E34C-97AA-4800-86AE-11E3F2E21B56', 'sid-BA08FF45-5AAE-4DF8-948A-0BB8E6A58AD6'], 'outgoing': ['sid-01C86089-2B4B-4E21-95F4-13E72C202A8F']}
# {'id': 'sid-D4E18DC8-FF82-4BD6-AF54-F2D5E8312BBF', 'name': 'EventBasedGateway4', 'incoming': ['sid-D04063E0-9F9D-492E-A1A2-94ED68FCE6AD'], 'outgoing': ['sid-5B15443F-955E-42EC-BF0F-50E2DB18F58B', 'sid-4F1A28D7-0F31-430C-887A-FC4710A0ED55', 'sid-717647AA-0156-4B23-85EC-867B51B7CAF8']}
# {'id': 'sid-DA73389A-E05F-4ED1-9244-C2F83BA62524', 'name': 'Date of expiry', 'incoming': ['sid-5B15443F-955E-42EC-BF0F-50E2DB18F58B'], 'outgoing': ['sid-8DA11120-2F83-4FBC-B0A9-2551BF21B442']}
# {'id': 'sid-23A3A372-5D39-43F3-A454-01B9F82F9C24', 'name': 'Opposition', 'incoming': ['sid-4F1A28D7-0F31-430C-887A-FC4710A0ED55'], 'outgoing': ['sid-7744950A-E48E-4F7E-B3CE-4BF3617828A9']}
# {'id': 'sid-B53B655A-A2A8-4357-8A1F-8DB8CDEC8B4A', 'name': 'Payment is made', 'incoming': ['sid-717647AA-0156-4B23-85EC-867B51B7CAF8'], 'outgoing': ['sid-2730F1E2-B1AC-4017-AC5A-6550D850891F']}
#
# Start Events:
# {'id': 'sid-ACB26722-5C46-466D-B69D-FBDEA6F68C21', 'name': 'Regression option available', 'incoming': [], 'outgoing': ['sid-3EB6D2A0-5780-4971-9A9A-A07F749C50E6']}
#
# End Events:
# {'id': 'sid-1B7C0D1D-5B98-46C0-8462-0686AC2A0E79', 'name': 'Closed', 'incoming': ['sid-F5C52874-91ED-4090-9D86-1F2035478864'], 'outgoing': []}

# %%
for task in tasks:
        for x in range(len(tasks)):
            len_task_in = 0
            len_task_out = 0
            len_task_in = len(task.incoming)
            len_task_out = len(task.outgoing)
            for length_in in range(len_task_in):
                for length_out in range(len_task_out):
                    if task.outgoing[length_out] == tasks[x].incoming[length_in]:
                        task.outgoing[length_out]=tasks[x].name
                        tasks[x].incoming[length_in]=task.name
        for gateway in gateways:
            length_out_gate = 0
            length_out_gate = len(gateway.outgoing)
            len_task_in = 0
            len_task_in = len(task.incoming)
            for length_in in range(len_task_in):
                for length_gate in range(length_out_gate):
                    if task.incoming[length_in] == gateway.outgoing[length_gate]:
                        gateway.outgoing[length_gate]=task.name
                        task.incoming[length_in]=gateway.name
            length_in_gate = 0
            length_in_gate = len(gateway.incoming)
            len_task_out = 0
            len_task_out = len(task.outgoing)
            for length_gate in range(length_in_gate):
                for length_out in range(len_task_out):
                    if task.outgoing[length_out] == gateway.incoming[length_gate]:
                        task.outgoing[length_out] = gateway.name
                        gateway.incoming[length_gate] = task.name
            for gateway2 in gateways:
                length_in_gate = 0
                length_in_gate = len(gateway2.incoming)
                length_out_gate = 0
                length_out_gate = len(gateway.outgoing)
                for length_gate_in in range(length_in_gate):
                    for length_gate_out in range(length_out_gate):
                        if gateway2.incoming[length_gate_in] == gateway.outgoing[length_gate_out]:
                            gateway2.incoming[length_gate_in] = gateway.name
                            gateway.outgoing[length_gate_out] = gateway2.name
        for start_event in start_events:
            len_task_in = len(task.incoming)
            start_len_out = len(start_event.outgoing)
            for start_event_out in range(start_len_out):
                for length_in in range(len_task_in):
                    if task.incoming[length_in] == start_event.outgoing[start_event_out]:
                        task.incoming[length_in] = start_event.name
                        start_event.outgoing[start_event_out] = task.name
                for gateway in gateways:
                    for gateway_in in range(len(gateway.incoming)):
                        if gateway.incoming[gateway_in]== start_event.outgoing[start_event_out]:
                            gateway.incoming[gateway_in] = start_event.name
                            start_event.outgoing[start_event_out]= gateway.name
        for end_event in end_events:
            len_task_out = len(task.outgoing)
            end_len_in = len(end_event.incoming)
            for end_event_in in range(end_len_in):
                for length_out in range(len_task_out):
                    if task.outgoing[length_out] == end_event.incoming[end_event_in]:
                        task.outgoing[length_out] = end_event.name
                        end_event.incoming[end_event_in] = task.name
                for gateway in gateways:
                    for gateway_out in range(len(gateway.outgoing)):
                        if gateway.outgoing[gateway_out]== end_event.incoming[end_event_in]:
                            gateway.outgoing[gateway_out] = end_event.name
                            end_event.incoming[end_event_in]= gateway.name

# %%
# Print parsed objects for verification
print("Tasks:")
for task in tasks:
    print(vars(task))

print("\nGateways:")
for gateway in gateways:
    print(vars(gateway))

print("\nStart Events:")
for start_event in start_events:
    print(vars(start_event))

print("\nEnd Events:")
for end_event in end_events:
    print(vars(end_event))
# Out:
# Tasks:
# {'id': 'sid-80F8D90D-AF83-498D-8975-7F963C3A034F', 'name': 'Check the case', 'incoming': ['Regression option available'], 'outgoing': ['ExclusiveGateway3']}
# {'id': 'sid-19B4518E-0889-43C1-89A8-DF4978C5DDE6', 'name': 'Send a message', 'incoming': ['Regression option available'], 'outgoing': ['Set process for resubmission']}
# {'id': 'sid-AA1D2C9A-F895-4C91-8FF4-272116373921', 'name': 'Set process for resubmission', 'incoming': ['Regress?'], 'outgoing': ['Date of expiry']}
# {'id': 'sid-B8696516-0D74-4F6F-AE20-2269402BFB15', 'name': 'Book payment receipt', 'incoming': ['Payment is made'], 'outgoing': ['ExclusiveGateway3']}
# {'id': 'sid-352C9B2D-2CAC-45A2-9A12-5F784CB3F938', 'name': 'Proceedings', 'incoming': ['Opposition'], 'outgoing': ['ExclusiveGateway2']}
# {'id': 'sid-425A8206-DF0B-4D1C-80EE-C4098F3A70CE', 'name': 'Debt collection service provider', 'incoming': ['EventBasedGateway4'], 'outgoing': ['ExclusiveGateway3']}
# {'id': 'sid-39FF2FBE-9F9A-44FE-BFDE-AE8F1C2D7607', 'name': 'Close', 'incoming': ['EventBasedGateway4'], 'outgoing': ['Closed']}
#
# Gateways:
# {'id': 'sid-E2391874-2CA6-47F1-9FE2-B9874D0BE466', 'name': 'Regress?', 'incoming': ['Regression option available'], 'outgoing': ['Objection?', 'ExclusiveGateway3']}
# {'id': 'sid-41B9B899-451C-486D-9016-CD8449D89E61', 'name': 'Objection?', 'incoming': ['Regress?'], 'outgoing': ['ExclusiveGateway2', 'ExclusiveGateway3']}
# {'id': 'sid-718E7B02-459D-4ADD-8E07-DC8F06DDD148', 'name': 'ExclusiveGateway2', 'incoming': ['EventBasedGateway4', 'Proceedings'], 'outgoing': ['Debt collection service provider']}
# {'id': 'sid-CED26085-A538-48D8-B7F7-71E626B265BD', 'name': 'ExclusiveGateway3', 'incoming': ['Check the case', 'EventBasedGateway4', 'EventBasedGateway4', 'EventBasedGateway4'], 'outgoing': ['Closed']}
# {'id': 'sid-D4E18DC8-FF82-4BD6-AF54-F2D5E8312BBF', 'name': 'EventBasedGateway4', 'incoming': ['Regress?'], 'outgoing': ['Close', 'Closed', 'ExclusiveGateway3']}
# {'id': 'sid-DA73389A-E05F-4ED1-9244-C2F83BA62524', 'name': 'Date of expiry', 'incoming': ['Set process for resubmission'], 'outgoing': ['ExclusiveGateway2']}
# {'id': 'sid-23A3A372-5D39-43F3-A454-01B9F82F9C24', 'name': 'Opposition', 'incoming': ['Regress?'], 'outgoing': ['ExclusiveGateway3']}
# {'id': 'sid-B53B655A-A2A8-4357-8A1F-8DB8CDEC8B4A', 'name': 'Payment is made', 'incoming': ['EventBasedGateway4'], 'outgoing': ['ExclusiveGateway3']}
#
# Start Events:
# {'id': 'sid-ACB26722-5C46-466D-B69D-FBDEA6F68C21', 'name': 'Regression option available', 'incoming': [], 'outgoing': ['Send a message']}
#
# End Events:
# {'id': 'sid-1B7C0D1D-5B98-46C0-8462-0686AC2A0E79', 'name': 'Closed', 'incoming': ['EventBasedGateway4'], 'outgoing': []}

# %%
string_output = f"The folowing describes a bpmn file {file_path}."
for start_event in start_events:
    length_start = len(start_event.outgoing)
    for i in range(length_start):
        outgoing = start_event.outgoing[i]
        #print(outgoing)
        for task in tasks:
            length_task = len(task.incoming)
            for x in range(length_task):
                #print(task.incoming[x])
                if task.incoming[x] == outgoing:
                    string_output += f"The Start event = {start_event.name} goes to task = {task.name}"
        for gateway in gateways:
            length_gate = len(gateway.incoming)
            for a in range(length_gate):
                if gateway.incoming[a] == outgoing:
                    string_output +=f"The Start event = {start_event.name} goes to gateway = {gateway.name}"

# %%
string_output
# Out:
# "The folowing describes a bpmn file uebung2_a5605713f817474d99a198ad61d52387_translated.bpmn. The Start_event = 'Regression option available' goes to task = 'Send a message. '"

# %%
string_output = f"The folowing describes a bpmn file {file_path}. "
for start_event in start_events:
    length_start = len(start_event.outgoing)
    for i in range(length_start):
        outgoing = start_event.outgoing[i]
        #print(outgoing)
        for task in tasks:
            if outgoing == task.name:
                string_output += f"The Start_event = '{start_event.name}' goes to task = '{task.name}.' "
        for gateway in gateways:
            if gateway.name == outgoing:
                 string_output +=f"The Start event = {start_event.name} goes to gateway = {gateway.name}"

# %%
string_output
# Out:
# "The folowing describes a bpmn file uebung2_a5605713f817474d99a198ad61d52387_translated.bpmn. The Start_event = 'Regression option available' goes to task = 'Send a message.' "

# %%
import xml.etree.ElementTree as ET

class Task:
    def __init__(self, id, name, incoming, outgoing):
        self.id = id
        self.name = name
        self.incoming = incoming
        self.outgoing = outgoing

class Gateway:
    def __init__(self, id, name, incoming, outgoing):
        self.id = id
        self.name = name
        self.incoming = incoming
        self.outgoing = outgoing

class StartEvent:
    def __init__(self, id, name, incoming, outgoing):
        self.id = id
        self.name = name
        self.incoming = incoming
        self.outgoing = outgoing

class EndEvent:
    def __init__(self, id, name, incoming, outgoing):
        self.id = id
        self.name = name
        self.incoming = incoming
        self.outgoing = outgoing

def parse_bpmn(file_path):
    tree = ET.parse(file_path)
    root = tree.getroot()

    tasks = []
    gateways = []
    start_events = []
    end_events = []

    # Namespace dictionary for finding elements with namespaces
    ns = {'bpmn': 'http://www.omg.org/spec/BPMN/20100524/MODEL'}

    # Parse tasks
    for element in root.findall('.//bpmn:task', ns):
        id = element.attrib.get('id')
        name = element.attrib.get('name', '')
        if name == '':
            created_name = 'Task'+f'{len(gateways)}'
            name = f'{created_name}'
        incoming = [e.text for e in element.findall('bpmn:incoming', ns)]
        outgoing = [e.text for e in element.findall('bpmn:outgoing', ns)]
        task = Task(id, name, incoming, outgoing)
        tasks.append(task)

    # Parse gateways
    for element in root.findall('.//bpmn:exclusiveGateway', ns):
        id = element.attrib.get('id')
        name = element.attrib.get('name', '')
        if name == '':
            created_name = 'ExclusiveGateway'+f'{len(gateways)}'
            name = f'{created_name}'
        incoming = [e.text for e in element.findall('bpmn:incoming', ns)]
        outgoing = [e.text for e in element.findall('bpmn:outgoing', ns)]
        gateway = Gateway(id, name, incoming, outgoing)
        gateways.append(gateway)
        
    for element in root.findall('.//bpmn:eventBasedGateway', ns):
        id = element.attrib.get('id')
        name = element.attrib.get('name', '')
        if name == '':
            created_name = 'EventBasedGateway'+f'{len(gateways)}'
            name = f'{created_name}'
        incoming = [e.text for e in element.findall('bpmn:incoming', ns)]
        outgoing = [e.text for e in element.findall('bpmn:outgoing', ns)]
        gateway = Gateway(id, name, incoming, outgoing)
        gateways.append(gateway)
        
    for element in root.findall('.//bpmn:inclusiveGateway', ns):
        id = element.attrib.get('id')
        name = element.attrib.get('name', '')
        if name == '':
            created_name = 'InclusivedGateway'+f'{len(gateways)}'
            name = f'{created_name}'
        incoming = [e.text for e in element.findall('bpmn:incoming', ns)]
        outgoing = [e.text for e in element.findall('bpmn:outgoing', ns)]
        gateway = Gateway(id, name, incoming, outgoing)
        gateways.append(gateway)
        
    for element in root.findall('.//bpmn:parallelGateway', ns):
        id = element.attrib.get('id')
        name = element.attrib.get('name', '')
        if name == '':
            created_name = 'ParallelGateway'+f'{len(gateways)}'
            name = f'{created_name}'
        incoming = [e.text for e in element.findall('bpmn:incoming', ns)]
        outgoing = [e.text for e in element.findall('bpmn:outgoing', ns)]
        gateway = Gateway(id, name, incoming, outgoing)
        gateways.append(gateway)
        
    for element in root.findall('.//bpmn:intermediateCatchEvent', ns):
        id = element.attrib.get('id')
        name = element.attrib.get('name', '')
        if name == '':
            created_name = 'IntermediateCatchEvent'+f'{len(gateways)}'
            name = f'{created_name}'
        incoming = [e.text for e in element.findall('bpmn:incoming', ns)]
        outgoing = [e.text for e in element.findall('bpmn:outgoing', ns)]
        gateway = Gateway(id, name, incoming, outgoing)
        gateways.append(gateway)

    # Parse start events
    for element in root.findall('.//bpmn:startEvent', ns):
        id = element.attrib.get('id')
        name = element.attrib.get('name', '')
        if name == '':
            created_name = 'StartEvent'+f'{len(gateways)}'
            name = f'{created_name}'
        incoming = [e.text for e in element.findall('bpmn:incoming', ns)]
        outgoing = [e.text for e in element.findall('bpmn:outgoing', ns)]
        start_event = StartEvent(id, name, incoming, outgoing)
        start_events.append(start_event)

    # Parse end events
    for element in root.findall('.//bpmn:endEvent', ns):
        id = element.attrib.get('id')
        name = element.attrib.get('name', '')
        if name == '':
            created_name = 'EndEvent'+f'{len(gateways)}'
            name = f'{created_name}'
        incoming = [e.text for e in element.findall('bpmn:incoming', ns)]
        outgoing = [e.text for e in element.findall('bpmn:outgoing', ns)]
        end_event = EndEvent(id, name, incoming, outgoing)
        end_events.append(end_event)

    return tasks, gateways, start_events, end_events

    


# Example usage
file_path = 'uebung2_a5605713f817474d99a198ad61d52387_translated.bpmn'
tasks, gateways, start_events, end_events = parse_bpmn(file_path)

for task in tasks:
        for x in range(len(tasks)):
            len_task_in = 0
            len_task_out = 0
            len_task_in = len(task.incoming)
            len_task_out = len(task.outgoing)
            for length_in in range(len_task_in):
                for length_out in range(len_task_out):
                    if task.outgoing[length_out] == tasks[x].incoming[length_in]:
                        task.outgoing[length_out]=tasks[x].name
                        tasks[x].incoming[length_in]=task.name
        for gateway in gateways:
            length_out_gate = 0
            length_out_gate = len(gateway.outgoing)
            len_task_in = 0
            len_task_in = len(task.incoming)
            for length_in in range(len_task_in):
                for length_gate in range(length_out_gate):
                    if task.incoming[length_in] == gateway.outgoing[length_gate]:
                        gateway.outgoing[length_gate]=task.name
                        task.incoming[length_in]=gateway.name
            length_in_gate = 0
            length_in_gate = len(gateway.incoming)
            len_task_out = 0
            len_task_out = len(task.outgoing)
            for length_gate in range(length_in_gate):
                for length_out in range(len_task_out):
                    if task.outgoing[length_out] == gateway.incoming[length_gate]:
                        task.outgoing[length_out] = gateway.name
                        gateway.incoming[length_gate] = task.name
            for gateway2 in gateways:
                length_in_gate = 0
                length_in_gate = len(gateway2.incoming)
                length_out_gate = 0
                length_out_gate = len(gateway.outgoing)
                for length_gate_in in range(length_in_gate):
                    for length_gate_out in range(length_out_gate):
                        if gateway2.incoming[length_gate_in] == gateway.outgoing[length_gate_out]:
                            gateway2.incoming[length_gate_in] = gateway.name
                            gateway.outgoing[length_gate_out] = gateway2.name
        for start_event in start_events:
            len_task_in = len(task.incoming)
            start_len_out = len(start_event.outgoing)
            for start_event_out in range(start_len_out):
                for length_in in range(len_task_in):
                    if task.incoming[length_in] == start_event.outgoing[start_event_out]:
                        task.incoming[length_in] = start_event.name
                        start_event.outgoing[start_event_out] = task.name
                for gateway in gateways:
                    for gateway_in in range(len(gateway.incoming)):
                        if gateway.incoming[gateway_in]== start_event.outgoing[start_event_out]:
                            gateway.incoming[gateway_in] = start_event.name
                            start_event.outgoing[start_event_out]= gateway.name
        for end_event in end_events:
            len_task_out = len(task.outgoing)
            end_len_in = len(end_event.incoming)
            for end_event_in in range(end_len_in):
                for length_out in range(len_task_out):
                    if task.outgoing[length_out] == end_event.incoming[end_event_in]:
                        task.outgoing[length_out] = end_event.name
                        end_event.incoming[end_event_in] = task.name
                for gateway in gateways:
                    for gateway_out in range(len(gateway.outgoing)):
                        if gateway.outgoing[gateway_out]== end_event.incoming[end_event_in]:
                            gateway.outgoing[gateway_out] = end_event.name
                            end_event.incoming[end_event_in]= gateway.name

# Print parsed objects for verification
print("Tasks:")
for task in tasks:
    print(vars(task))

print("\nGateways:")
for gateway in gateways:
    print(vars(gateway))

print("\nStart Events:")
for start_event in start_events:
    print(vars(start_event))

print("\nEnd Events:")
for end_event in end_events:
    print(vars(end_event))
# Out:
# Tasks:
# {'id': 'sid-80F8D90D-AF83-498D-8975-7F963C3A034F', 'name': 'Check the case', 'incoming': ['Regression option available'], 'outgoing': ['ExclusiveGateway3']}
# {'id': 'sid-19B4518E-0889-43C1-89A8-DF4978C5DDE6', 'name': 'Send a message', 'incoming': ['Regression option available'], 'outgoing': ['Set process for resubmission']}
# {'id': 'sid-AA1D2C9A-F895-4C91-8FF4-272116373921', 'name': 'Set process for resubmission', 'incoming': ['Regress?'], 'outgoing': ['Date of expiry']}
# {'id': 'sid-B8696516-0D74-4F6F-AE20-2269402BFB15', 'name': 'Book payment receipt', 'incoming': ['Payment is made'], 'outgoing': ['ExclusiveGateway3']}
# {'id': 'sid-352C9B2D-2CAC-45A2-9A12-5F784CB3F938', 'name': 'Proceedings', 'incoming': ['Opposition'], 'outgoing': ['ExclusiveGateway2']}
# {'id': 'sid-425A8206-DF0B-4D1C-80EE-C4098F3A70CE', 'name': 'Debt collection service provider', 'incoming': ['EventBasedGateway4'], 'outgoing': ['ExclusiveGateway3']}
# {'id': 'sid-39FF2FBE-9F9A-44FE-BFDE-AE8F1C2D7607', 'name': 'Close', 'incoming': ['EventBasedGateway4'], 'outgoing': ['Closed']}
#
# Gateways:
# {'id': 'sid-E2391874-2CA6-47F1-9FE2-B9874D0BE466', 'name': 'Regress?', 'incoming': ['Regression option available'], 'outgoing': ['Objection?', 'ExclusiveGateway3']}
# {'id': 'sid-41B9B899-451C-486D-9016-CD8449D89E61', 'name': 'Objection?', 'incoming': ['Regress?'], 'outgoing': ['ExclusiveGateway2', 'ExclusiveGateway3']}
# {'id': 'sid-718E7B02-459D-4ADD-8E07-DC8F06DDD148', 'name': 'ExclusiveGateway2', 'incoming': ['EventBasedGateway4', 'Proceedings'], 'outgoing': ['Debt collection service provider']}
# {'id': 'sid-CED26085-A538-48D8-B7F7-71E626B265BD', 'name': 'ExclusiveGateway3', 'incoming': ['Check the case', 'EventBasedGateway4', 'EventBasedGateway4', 'EventBasedGateway4'], 'outgoing': ['Closed']}
# {'id': 'sid-D4E18DC8-FF82-4BD6-AF54-F2D5E8312BBF', 'name': 'EventBasedGateway4', 'incoming': ['Regress?'], 'outgoing': ['Close', 'Closed', 'ExclusiveGateway3']}
# {'id': 'sid-DA73389A-E05F-4ED1-9244-C2F83BA62524', 'name': 'Date of expiry', 'incoming': ['Set process for resubmission'], 'outgoing': ['ExclusiveGateway2']}
# {'id': 'sid-23A3A372-5D39-43F3-A454-01B9F82F9C24', 'name': 'Opposition', 'incoming': ['Regress?'], 'outgoing': ['ExclusiveGateway3']}
# {'id': 'sid-B53B655A-A2A8-4357-8A1F-8DB8CDEC8B4A', 'name': 'Payment is made', 'incoming': ['EventBasedGateway4'], 'outgoing': ['ExclusiveGateway3']}
#
# Start Events:
# {'id': 'sid-ACB26722-5C46-466D-B69D-FBDEA6F68C21', 'name': 'Regression option available', 'incoming': [], 'outgoing': ['Send a message']}
#
# End Events:
# {'id': 'sid-1B7C0D1D-5B98-46C0-8462-0686AC2A0E79', 'name': 'Closed', 'incoming': ['EventBasedGateway4'], 'outgoing': []}

# %%
import os
import xml.etree.ElementTree as ET

class Task:
    def __init__(self, id, name, incoming, outgoing):
        self.id = id
        self.name = name
        self.incoming = incoming
        self.outgoing = outgoing

class Gateway:
    def __init__(self, id, name, incoming, outgoing):
        self.id = id
        self.name = name
        self.incoming = incoming
        self.outgoing = outgoing

class StartEvent:
    def __init__(self, id, name, incoming, outgoing):
        self.id = id
        self.name = name
        self.incoming = incoming
        self.outgoing = outgoing

class EndEvent:
    def __init__(self, id, name, incoming, outgoing):
        self.id = id
        self.name = name
        self.incoming = incoming
        self.outgoing = outgoing

def parse_bpmn(file_path):
    tree = ET.parse(file_path)
    root = tree.getroot()

    tasks = []
    gateways = []
    start_events = []
    end_events = []

    ns = {'bpmn': 'http://www.omg.org/spec/BPMN/20100524/MODEL'}

    for element in root.findall('.//bpmn:task', ns):
        id = element.attrib.get('id')
        name = element.attrib.get('name', '')
        if name == '':
            name = 'Task' + f'{len(tasks)}'
        incoming = [e.text for e in element.findall('bpmn:incoming', ns)]
        outgoing = [e.text for e in element.findall('bpmn:outgoing', ns)]
        task = Task(id, name, incoming, outgoing)
        tasks.append(task)

    for element in root.findall('.//bpmn:exclusiveGateway', ns):
        id = element.attrib.get('id')
        name = element.attrib.get('name', '')
        if name == '':
            name = 'ExclusiveGateway' + f'{len(gateways)}'
        incoming = [e.text for e in element.findall('bpmn:incoming', ns)]
        outgoing = [e.text for e in element.findall('bpmn:outgoing', ns)]
        gateway = Gateway(id, name, incoming, outgoing)
        gateways.append(gateway)
        
    for element in root.findall('.//bpmn:eventBasedGateway', ns):
        id = element.attrib.get('id')
        name = element.attrib.get('name', '')
        if name == '':
            name = 'EventBasedGateway' + f'{len(gateways)}'
        incoming = [e.text for e in element.findall('bpmn:incoming', ns)]
        outgoing = [e.text for e in element.findall('bpmn:outgoing', ns)]
        gateway = Gateway(id, name, incoming, outgoing)
        gateways.append(gateway)
        
    for element in root.findall('.//bpmn:inclusiveGateway', ns):
        id = element.attrib.get('id')
        name = element.attrib.get('name', '')
        if name == '':
            name = 'InclusiveGateway' + f'{len(gateways)}'
        incoming = [e.text for e in element.findall('bpmn:incoming', ns)]
        outgoing = [e.text for e in element.findall('bpmn:outgoing', ns)]
        gateway = Gateway(id, name, incoming, outgoing)
        gateways.append(gateway)
        
    for element in root.findall('.//bpmn:parallelGateway', ns):
        id = element.attrib.get('id')
        name = element.attrib.get('name', '')
        if name == '':
            name = 'ParallelGateway' + f'{len(gateways)}'
        incoming = [e.text for e in element.findall('bpmn:incoming', ns)]
        outgoing = [e.text for e in element.findall('bpmn:outgoing', ns)]
        gateway = Gateway(id, name, incoming, outgoing)
        gateways.append(gateway)
        
    for element in root.findall('.//bpmn:intermediateCatchEvent', ns):
        id = element.attrib.get('id')
        name = element.attrib.get('name', '')
        if name == '':
            name = 'IntermediateCatchEvent' + f'{len(gateways)}'
        incoming = [e.text for e in element.findall('bpmn:incoming', ns)]
        outgoing = [e.text for e in element.findall('bpmn:outgoing', ns)]
        gateway = Gateway(id, name, incoming, outgoing)
        gateways.append(gateway)

    for element in root.findall('.//bpmn:startEvent', ns):
        id = element.attrib.get('id')
        name = element.attrib.get('name', '')
        if name == '':
            name = 'StartEvent' + f'{len(start_events)}'
        incoming = [e.text for e in element.findall('bpmn:incoming', ns)]
        outgoing = [e.text for e in element.findall('bpmn:outgoing', ns)]
        start_event = StartEvent(id, name, incoming, outgoing)
        start_events.append(start_event)

    for element in root.findall('.//bpmn:endEvent', ns):
        id = element.attrib.get('id')
        name = element.attrib.get('name', '')
        if name == '':
            name = 'EndEvent' + f'{len(end_events)}'
        incoming = [e.text for e in element.findall('bpmn:incoming', ns)]
        outgoing = [e.text for e in element.findall('bpmn:outgoing', ns)]
        end_event = EndEvent(id, name, incoming, outgoing)
        end_events.append(end_event)

    return tasks, gateways, start_events, end_events

def process_bpmn_objects(tasks, gateways, start_events, end_events):
    for task in tasks:
        for x in range(len(tasks)):
            len_task_in = len(task.incoming)
            len_task_out = len(task.outgoing)
            for length_in in range(len_task_in):
                for length_out in range(len_task_out):
                    if task.outgoing[length_out] == tasks[x].incoming[length_in]:
                        task.outgoing[length_out] = tasks[x].name
                        tasks[x].incoming[length_in] = task.name
        for gateway in gateways:
            length_out_gate = len(gateway.outgoing)
            len_task_in = len(task.incoming)
            for length_in in range(len_task_in):
                for length_gate in range(length_out_gate):
                    if task.incoming[length_in] == gateway.outgoing[length_gate]:
                        gateway.outgoing[length_gate] = task.name
                        task.incoming[length_in] = gateway.name
            length_in_gate = len(gateway.incoming)
            len_task_out = len(task.outgoing)
            for length_gate in range(length_in_gate):
                for length_out in range(len_task_out):
                    if task.outgoing[length_out] == gateway.incoming[length_gate]:
                        task.outgoing[length_out] = gateway.name
                        gateway.incoming[length_gate] = task.name
            for gateway2 in gateways:
                length_in_gate = len(gateway2.incoming)
                length_out_gate = len(gateway.outgoing)
                for length_gate_in in range(length_in_gate):
                    for length_gate_out in range(length_out_gate):
                        if gateway2.incoming[length_gate_in] == gateway.outgoing[length_gate_out]:
                            gateway2.incoming[length_gate_in] = gateway.name
                            gateway.outgoing[length_gate_out] = gateway2.name
        for start_event in start_events:
            len_task_in = len(task.incoming)
            start_len_out = len(start_event.outgoing)
            for start_event_out in range(start_len_out):
                for length_in in range(len_task_in):
                    if task.incoming[length_in] == start_event.outgoing[start_event_out]:
                        task.incoming[length_in] = start_event.name
                        start_event.outgoing[start_event_out] = task.name
                for gateway in gateways:
                    for gateway_in in range(len(gateway.incoming)):
                        if gateway.incoming[gateway_in] == start_event.outgoing[start_event_out]:
                            gateway.incoming[gateway_in] = start_event.name
                            start_event.outgoing[start_event_out] = gateway.name
        for end_event in end_events:
            len_task_out = len(task.outgoing)
            end_len_in = len(end_event.incoming)
            for end_event_in in range(end_len_in):
                for length_out in range(len_task_out):
                    if task.outgoing[length_out] == end_event.incoming[end_event_in]:
                        task.outgoing[length_out] = end_event.name
                        end_event.incoming[end_event_in] = task.name
                for gateway in gateways:
                    for gateway_out in range(len(gateway.outgoing)):
                        if gateway.outgoing[gateway_out] == end_event.incoming[end_event_in]:
                            gateway.outgoing[gateway_out] = end_event.name
                            end_event.incoming[end_event_in] = gateway.name

def save_processed_objects(file_path, tasks, gateways, start_events, end_events):
    with open(file_path, 'w') as f:
        f.write("Tasks:\n")
        for task in tasks:
            f.write(str(vars(task)) + "\n")
        f.write("\nGateways:\n")
        for gateway in gateways:
            f.write(str(vars(gateway)) + "\n")
        f.write("\nStart Events:\n")
        for start_event in start_events:
            f.write(str(vars(start_event)) + "\n")
        f.write("\nEnd Events:\n")
        for end_event in end_events:
            f.write(str(vars(end_event)) + "\n")

def process_all_bpmn_files(input_directory, output_directory):
    if not os.path.exists(output_directory):
        os.makedirs(output_directory)

    for filename in os.listdir(input_directory):
        if filename.endswith(".bpmn"):
            input_file_path = os.path.join(input_directory, filename)
            output_file_path = os.path.join(output_directory, f"processed_{filename}.txt")

            tasks, gateways, start_events, end_events = parse_bpmn(input_file_path)
            process_bpmn_objects(tasks, gateways, start_events, end_events)
            save_processed_objects(output_file_path, tasks, gateways, start_events, end_events)
            
            print(f"Processed {filename} and saved to {output_file_path}")

# Directory containing .bpmn files
input_directory = './the process/'
# Directory to save processed files
output_directory = './output/'

# Process all .bpmn files in the input directory
process_all_bpmn_files(input_directory, output_directory)
# Out:
# Processed -_Schufa_9831eb834a924b9f9c4591000c9387ef_translated.bpmn and saved to ./output/processed_-_Schufa_9831eb834a924b9f9c4591000c9387ef_translated.bpmn.txt
# Processed -_Task_1_cb967b14c29e4f8f9d182d67559547a2_translated.bpmn and saved to ./output/processed_-_Task_1_cb967b14c29e4f8f9d182d67559547a2_translated.bpmn.txt
# Processed -_Task_3_84c455b8b0db45b388e7e176598502a9_translated.bpmn and saved to ./output/processed_-_Task_3_84c455b8b0db45b388e7e176598502a9_translated.bpmn.txt
# Processed -__bung_1_887e88cab0d94585a5c6fb3e3ac12469_translated.bpmn and saved to ./output/processed_-__bung_1_887e88cab0d94585a5c6fb3e3ac12469_translated.bpmn.txt
# Processed -__bung_3_2bdcf0e75ba0441a9c2e775e9b3555b8_translated.bpmn and saved to ./output/processed_-__bung_3_2bdcf0e75ba0441a9c2e775e9b3555b8_translated.bpmn.txt
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 221
#     218 output_directory = './output/'
#     220 # Process all .bpmn files in the input directory
# --> 221 process_all_bpmn_files(input_directory, output_directory)
#
# Cell In[5], line 210, in process_all_bpmn_files(input_directory, output_directory)
#     207 output_file_path = os.path.join(output_directory, f"processed_{filename}.txt")
#     209 tasks, gateways, start_events, end_events = parse_bpmn(input_file_path)
# --> 210 process_bpmn_objects(tasks, gateways, start_events, end_events)
#     211 save_processed_objects(output_file_path, tasks, gateways, start_events, end_events)
#     213 print(f"Processed {filename} and saved to {output_file_path}")
#
# Cell In[5], line 132, in process_bpmn_objects(tasks, gateways, start_events, end_events)
#     130 for length_in in range(len_task_in):
#     131     for length_out in range(len_task_out):
# --> 132         if task.outgoing[length_out] == tasks[x].incoming[length_in]:
#     133             task.outgoing[length_out] = tasks[x].name
#     134             tasks[x].incoming[length_in] = task.name
#
# IndexError: list index out of range

# %%
import os
import xml.etree.ElementTree as ET
import logging

class Task:
    def __init__(self, id, name, incoming, outgoing):
        self.id = id
        self.name = name
        self.incoming = incoming
        self.outgoing = outgoing

class Gateway:
    def __init__(self, id, name, incoming, outgoing):
        self.id = id
        self.name = name
        self.incoming = incoming
        self.outgoing = outgoing

class StartEvent:
    def __init__(self, id, name, incoming, outgoing):
        self.id = id
        self.name = name
        self.incoming = incoming
        self.outgoing = outgoing

class EndEvent:
    def __init__(self, id, name, incoming, outgoing):
        self.id = id
        self.name = name
        self.incoming = incoming
        self.outgoing = outgoing

def parse_bpmn(file_path):
    tree = ET.parse(file_path)
    root = tree.getroot()

    tasks = []
    gateways = []
    start_events = []
    end_events = []

    ns = {'bpmn': 'http://www.omg.org/spec/BPMN/20100524/MODEL'}

    for element in root.findall('.//bpmn:task', ns):
        id = element.attrib.get('id')
        name = element.attrib.get('name', '')
        if name == '':
            name = 'Task' + f'{len(tasks)}'
        incoming = [e.text for e in element.findall('bpmn:incoming', ns)]
        outgoing = [e.text for e in element.findall('bpmn:outgoing', ns)]
        task = Task(id, name, incoming, outgoing)
        tasks.append(task)

    for element in root.findall('.//bpmn:exclusiveGateway', ns):
        id = element.attrib.get('id')
        name = element.attrib.get('name', '')
        if name == '':
            name = 'ExclusiveGateway' + f'{len(gateways)}'
        incoming = [e.text for e in element.findall('bpmn:incoming', ns)]
        outgoing = [e.text for e in element.findall('bpmn:outgoing', ns)]
        gateway = Gateway(id, name, incoming, outgoing)
        gateways.append(gateway)
        
    for element in root.findall('.//bpmn:eventBasedGateway', ns):
        id = element.attrib.get('id')
        name = element.attrib.get('name', '')
        if name == '':
            name = 'EventBasedGateway' + f'{len(gateways)}'
        incoming = [e.text for e in element.findall('bpmn:incoming', ns)]
        outgoing = [e.text for e in element.findall('bpmn:outgoing', ns)]
        gateway = Gateway(id, name, incoming, outgoing)
        gateways.append(gateway)
        
    for element in root.findall('.//bpmn:inclusiveGateway', ns):
        id = element.attrib.get('id')
        name = element.attrib.get('name', '')
        if name == '':
            name = 'InclusiveGateway' + f'{len(gateways)}'
        incoming = [e.text for e in element.findall('bpmn:incoming', ns)]
        outgoing = [e.text for e in element.findall('bpmn:outgoing', ns)]
        gateway = Gateway(id, name, incoming, outgoing)
        gateways.append(gateway)
        
    for element in root.findall('.//bpmn:parallelGateway', ns):
        id = element.attrib.get('id')
        name = element.attrib.get('name', '')
        if name == '':
            name = 'ParallelGateway' + f'{len(gateways)}'
        incoming = [e.text for e in element.findall('bpmn:incoming', ns)]
        outgoing = [e.text for e in element.findall('bpmn:outgoing', ns)]
        gateway = Gateway(id, name, incoming, outgoing)
        gateways.append(gateway)
        
    for element in root.findall('.//bpmn:intermediateCatchEvent', ns):
        id = element.attrib.get('id')
        name = element.attrib.get('name', '')
        if name == '':
            name = 'IntermediateCatchEvent' + f'{len(gateways)}'
        incoming = [e.text for e in element.findall('bpmn:incoming', ns)]
        outgoing = [e.text for e in element.findall('bpmn:outgoing', ns)]
        gateway = Gateway(id, name, incoming, outgoing)
        gateways.append(gateway)

    for element in root.findall('.//bpmn:startEvent', ns):
        id = element.attrib.get('id')
        name = element.attrib.get('name', '')
        if name == '':
            name = 'StartEvent' + f'{len(start_events)}'
        incoming = [e.text for e in element.findall('bpmn:incoming', ns)]
        outgoing = [e.text for e in element.findall('bpmn:outgoing', ns)]
        start_event = StartEvent(id, name, incoming, outgoing)
        start_events.append(start_event)

    for element in root.findall('.//bpmn:endEvent', ns):
        id = element.attrib.get('id')
        name = element.attrib.get('name', '')
        if name == '':
            name = 'EndEvent' + f'{len(end_events)}'
        incoming = [e.text for e in element.findall('bpmn:incoming', ns)]
        outgoing = [e.text for e in element.findall('bpmn:outgoing', ns)]
        end_event = EndEvent(id, name, incoming, outgoing)
        end_events.append(end_event)

    return tasks, gateways, start_events, end_events

def process_bpmn_objects(tasks, gateways, start_events, end_events):
    for task in tasks:
        for x in range(len(tasks)):
            len_task_in = len(task.incoming)
            len_task_out = len(task.outgoing)
            for length_in in range(len_task_in):
                for length_out in range(len_task_out):
                    if task.outgoing[length_out] == tasks[x].incoming[length_in]:
                        task.outgoing[length_out] = tasks[x].name
                        tasks[x].incoming[length_in] = task.name
        for gateway in gateways:
            length_out_gate = len(gateway.outgoing)
            len_task_in = len(task.incoming)
            for length_in in range(len_task_in):
                for length_gate in range(length_out_gate):
                    if task.incoming[length_in] == gateway.outgoing[length_gate]:
                        gateway.outgoing[length_gate] = task.name
                        task.incoming[length_in] = gateway.name
            length_in_gate = len(gateway.incoming)
            len_task_out = len(task.outgoing)
            for length_gate in range(length_in_gate):
                for length_out in range(len_task_out):
                    if task.outgoing[length_out] == gateway.incoming[length_gate]:
                        task.outgoing[length_out] = gateway.name
                        gateway.incoming[length_gate] = task.name
            for gateway2 in gateways:
                length_in_gate = len(gateway2.incoming)
                length_out_gate = len(gateway.outgoing)
                for length_gate_in in range(length_in_gate):
                    for length_gate_out in range(length_out_gate):
                        if gateway2.incoming[length_gate_in] == gateway.outgoing[length_gate_out]:
                            gateway2.incoming[length_gate_in] = gateway.name
                            gateway.outgoing[length_gate_out] = gateway2.name
        for start_event in start_events:
            len_task_in = len(task.incoming)
            start_len_out = len(start_event.outgoing)
            for start_event_out in range(start_len_out):
                for length_in in range(len_task_in):
                    if task.incoming[length_in] == start_event.outgoing[start_event_out]:
                        task.incoming[length_in] = start_event.name
                        start_event.outgoing[start_event_out] = task.name
                for gateway in gateways:
                    for gateway_in in range(len(gateway.incoming)):
                        if gateway.incoming[gateway_in] == start_event.outgoing[start_event_out]:
                            gateway.incoming[gateway_in] = start_event.name
                            start_event.outgoing[start_event_out] = gateway.name
        for end_event in end_events:
            len_task_out = len(task.outgoing)
            end_len_in = len(end_event.incoming)
            for end_event_in in range(end_len_in):
                for length_out in range(len_task_out):
                    if task.outgoing[length_out] == end_event.incoming[end_event_in]:
                        task.outgoing[length_out] = end_event.name
                        end_event.incoming[end_event_in] = task.name
                for gateway in gateways:
                    for gateway_out in range(len(gateway.outgoing)):
                        if gateway.outgoing[gateway_out] == end_event.incoming[end_event_in]:
                            gateway.outgoing[gateway_out] = end_event.name
                            end_event.incoming[end_event_in] = gateway.name

def save_processed_objects(file_path, tasks, gateways, start_events, end_events):
    with open(file_path, 'w') as f:
        f.write("Tasks:\n")
        for task in tasks:
            f.write(str(vars(task)) + "\n")
        f.write("\nGateways:\n")
        for gateway in gateways:
            f.write(str(vars(gateway)) + "\n")
        f.write("\nStart Events:\n")
        for start_event in start_events:
            f.write(str(vars(start_event)) + "\n")
        f.write("\nEnd Events:\n")
        for end_event in end_events:
            f.write(str(vars(end_event)) + "\n")

def process_all_bpmn_files(input_directory, output_directory):
    if not os.path.exists(output_directory):
        os.makedirs(output_directory)

    for filename in os.listdir(input_directory):
        if filename.endswith(".bpmn"):
            input_file_path = os.path.join(input_directory, filename)
            output_file_path = os.path.join(output_directory, f"processed_{filename}.txt")

            try:
                tasks, gateways, start_events, end_events = parse_bpmn(input_file_path)
                process_bpmn_objects(tasks, gateways, start_events, end_events)
                save_processed_objects(output_file_path, tasks, gateways, start_events, end_events)
                print(f"Processed {filename} and saved to {output_file_path}")
            except Exception as e:
                logging.error(f"Error processing {filename}: {e}")

# Set up logging
logging.basicConfig(filename='bpmn_processing.log', level=logging.ERROR)

# Directory containing .bpmn files
input_directory = './the process/'
# Directory to save processed files
output_directory = './output_newbranches/'

# Process all .bpmn files in the input directory
process_all_bpmn_files(input_directory, output_directory)
# Out:
# Processed -_Schufa_9831eb834a924b9f9c4591000c9387ef_translated.bpmn and saved to ./output/processed_-_Schufa_9831eb834a924b9f9c4591000c9387ef_translated.bpmn.txt
# Processed -_Task_1_cb967b14c29e4f8f9d182d67559547a2_translated.bpmn and saved to ./output/processed_-_Task_1_cb967b14c29e4f8f9d182d67559547a2_translated.bpmn.txt
# Processed -_Task_3_84c455b8b0db45b388e7e176598502a9_translated.bpmn and saved to ./output/processed_-_Task_3_84c455b8b0db45b388e7e176598502a9_translated.bpmn.txt
# Processed -__bung_1_887e88cab0d94585a5c6fb3e3ac12469_translated.bpmn and saved to ./output/processed_-__bung_1_887e88cab0d94585a5c6fb3e3ac12469_translated.bpmn.txt
# Processed -__bung_3_2bdcf0e75ba0441a9c2e775e9b3555b8_translated.bpmn and saved to ./output/processed_-__bung_3_2bdcf0e75ba0441a9c2e775e9b3555b8_translated.bpmn.txt
# Processed -__bung_7_0baaba4c86fa488e88f74bd7dabad073_translated.bpmn and saved to ./output/processed_-__bung_7_0baaba4c86fa488e88f74bd7dabad073_translated.bpmn.txt
# Processed -__bung_7_fe81e155c2d94fe084b74e23102f684f_translated.bpmn and saved to ./output/processed_-__bung_7_fe81e155c2d94fe084b74e23102f684f_translated.bpmn.txt
# Processed -__bung_8_d53e88c969ba4f81b6a2fd1053bd704d_translated.bpmn and saved to ./output/processed_-__bung_8_d53e88c969ba4f81b6a2fd1053bd704d_translated.bpmn.txt
# Processed 01Warenversand_39f5a5faf1c5480a9b04bc7bb39fb095_translated.bpmn and saved to ./output/processed_01Warenversand_39f5a5faf1c5480a9b04bc7bb39fb095_translated.bpmn.txt
# Processed 01_-_Vorbereitung_Warenversand_e29ad857608345f4a3c8ee5eefc44129_translated.bpmn and saved to ./output/processed_01_-_Vorbereitung_Warenversand_e29ad857608345f4a3c8ee5eefc44129_translated.bpmn.txt
# Processed 02Regressnahme_fe2a7ad5737d4474908913c52950a268_translated.bpmn and saved to ./output/processed_02Regressnahme_fe2a7ad5737d4474908913c52950a268_translated.bpmn.txt
# Processed 03_-_Regressnahme_25cbac3aa336467199f85f29f8db84c5_translated.bpmn and saved to ./output/processed_03_-_Regressnahme_25cbac3aa336467199f85f29f8db84c5_translated.bpmn.txt
# Processed 03_Regressfall_7fa68b043d164a6d9bccbfcdb31b42db_translated.bpmn and saved to ./output/processed_03_Regressfall_7fa68b043d164a6d9bccbfcdb31b42db_translated.bpmn.txt
# Processed 04Selbstbedienungsrestaurant_ed827e5edd6249fca7269c8f5ff81450_translated.bpmn and saved to ./output/processed_04Selbstbedienungsrestaurant_ed827e5edd6249fca7269c8f5ff81450_translated.bpmn.txt
# Processed 04__Schufa_2f43881cfdd54aa2b75ea1ba63060e61_translated.bpmn and saved to ./output/processed_04__Schufa_2f43881cfdd54aa2b75ea1ba63060e61_translated.bpmn.txt
# Processed 04__Schufa__neu__6d05933288214e2e9aff97e3f06ac825_translated.bpmn and saved to ./output/processed_04__Schufa__neu__6d05933288214e2e9aff97e3f06ac825_translated.bpmn.txt
# Processed 05Schufascoring_9a98a9585a984a6aba5deadb7cf346b9_translated.bpmn and saved to ./output/processed_05Schufascoring_9a98a9585a984a6aba5deadb7cf346b9_translated.bpmn.txt
# Processed 07_-_Schufascoring_4787494aaa1543539717c95ca3dca6c8_translated.bpmn and saved to ./output/processed_07_-_Schufascoring_4787494aaa1543539717c95ca3dca6c8_translated.bpmn.txt
# Processed 08_Restaurant_e841593ad625450d951d0558b35d6c02_translated.bpmn and saved to ./output/processed_08_Restaurant_e841593ad625450d951d0558b35d6c02_translated.bpmn.txt
# Processed 1.__bung_Vorbereitung_des_Warenversand_b1924b3dfc1a48b48375847178d53af3_translated.bpmn and saved to ./output/processed_1.__bung_Vorbereitung_des_Warenversand_b1924b3dfc1a48b48375847178d53af3_translated.bpmn.txt
# Processed 3-Regressnahme_abaeb1bfe7cb46448a9126aa13cc0084_translated.bpmn and saved to ./output/processed_3-Regressnahme_abaeb1bfe7cb46448a9126aa13cc0084_translated.bpmn.txt
# Processed 3.__bung_Regressnahme_6ad77fb7929143dd85d80f6b49a4ed7a_translated.bpmn and saved to ./output/processed_3.__bung_Regressnahme_6ad77fb7929143dd85d80f6b49a4ed7a_translated.bpmn.txt
# Processed 3.__bung_Schufascoring_05b570bf728346a7b552f0a8d64d49da_translated.bpmn and saved to ./output/processed_3.__bung_Schufascoring_05b570bf728346a7b552f0a8d64d49da_translated.bpmn.txt
# Processed 4._Schufascoring_ab3591e0a0ad4280b33f60e7cf710988_translated.bpmn and saved to ./output/processed_4._Schufascoring_ab3591e0a0ad4280b33f60e7cf710988_translated.bpmn.txt
# Processed 5._Selbstbedienungsrestaurant_8360972545fd4ec983f0e99db7b83cd3_translated.bpmn and saved to ./output/processed_5._Selbstbedienungsrestaurant_8360972545fd4ec983f0e99db7b83cd3_translated.bpmn.txt
# Processed 5._Selbstbedienungsrestaurant_f65c8daf16aa41999a24ad6339e1ec8a_translated.bpmn and saved to ./output/processed_5._Selbstbedienungsrestaurant_f65c8daf16aa41999a24ad6339e1ec8a_translated.bpmn.txt
# Processed 7-Schufascoring_ff8f009b0114494894845b8a721d956d_translated.bpmn and saved to ./output/processed_7-Schufascoring_ff8f009b0114494894845b8a721d956d_translated.bpmn.txt
# Processed 7.__bung_Schufascoring_2412bb6ac495488687185c74dcdcaf90_translated.bpmn and saved to ./output/processed_7.__bung_Schufascoring_2412bb6ac495488687185c74dcdcaf90_translated.bpmn.txt
# Processed 8-SB-Restaurant_50db89bd483140b893e94689c43adc28_translated.bpmn and saved to ./output/processed_8-SB-Restaurant_50db89bd483140b893e94689c43adc28_translated.bpmn.txt
# Processed 8.__bung_Selbstbedienungsrestaurant_ee3d9b9c56d0402393fa2c4b64cd45bd_translated.bpmn and saved to ./output/processed_8.__bung_Selbstbedienungsrestaurant_ee3d9b9c56d0402393fa2c4b64cd45bd_translated.bpmn.txt
# Processed A7_b0448c6829944874a20606ff351eecd7_translated.bpmn and saved to ./output/processed_A7_b0448c6829944874a20606ff351eecd7_translated.bpmn.txt
# Processed AR_Selbstbedienungsrestaurant_0480957f29034d5890e1c7627876fb1a_translated.bpmn and saved to ./output/processed_AR_Selbstbedienungsrestaurant_0480957f29034d5890e1c7627876fb1a_translated.bpmn.txt
# Processed Aufgabe1_Warenversand_9c7ad926c64d41e0b176fa052ea60ef6_translated.bpmn and saved to ./output/processed_Aufgabe1_Warenversand_9c7ad926c64d41e0b176fa052ea60ef6_translated.bpmn.txt
# Processed Aufgabe1_Warenversand_Alternative_cdc7b6dcb6c142c18ba2a1e0ef9b2b1e_translated.bpmn and saved to ./output/processed_Aufgabe1_Warenversand_Alternative_cdc7b6dcb6c142c18ba2a1e0ef9b2b1e_translated.bpmn.txt
# Processed Aufgabe3_Regressnahme_7bffccf60796457ea72f8f8e17b82193_translated.bpmn and saved to ./output/processed_Aufgabe3_Regressnahme_7bffccf60796457ea72f8f8e17b82193_translated.bpmn.txt
# Processed Aufgabe7_852ebf89163047f98afe469f8dcd803a_translated.bpmn and saved to ./output/processed_Aufgabe7_852ebf89163047f98afe469f8dcd803a_translated.bpmn.txt
# Processed Aufgabe7_Schufascoring_86493d048c7d45d387dd1b0fc0539c8f_translated.bpmn and saved to ./output/processed_Aufgabe7_Schufascoring_86493d048c7d45d387dd1b0fc0539c8f_translated.bpmn.txt
# Processed Aufgabe7_Schufascoring_Falsch_e881faad883d4dd9ac2d5ff8513bbaf2_translated.bpmn and saved to ./output/processed_Aufgabe7_Schufascoring_Falsch_e881faad883d4dd9ac2d5ff8513bbaf2_translated.bpmn.txt
# Processed Aufgabe8_Selbstbedienungsrestaurant_9c9fec2b44ea43439db65e7b08c5bb7d_translated.bpmn and saved to ./output/processed_Aufgabe8_Selbstbedienungsrestaurant_9c9fec2b44ea43439db65e7b08c5bb7d_translated.bpmn.txt
# Processed Aufgabe_1_-_Warenversand_aa918f1b0a5e40d997a6b52bb21df01c_translated.bpmn and saved to ./output/processed_Aufgabe_1_-_Warenversand_aa918f1b0a5e40d997a6b52bb21df01c_translated.bpmn.txt
# Processed Aufgabe_1_13fffd5830674bb8895ca7f4b4ac7546_translated.bpmn and saved to ./output/processed_Aufgabe_1_13fffd5830674bb8895ca7f4b4ac7546_translated.bpmn.txt
# Processed Aufgabe_1_38ebadc4d2744116ba565d266ebcc6af_translated.bpmn and saved to ./output/processed_Aufgabe_1_38ebadc4d2744116ba565d266ebcc6af_translated.bpmn.txt
# Processed Aufgabe_1_5b60340cf441488b9f9fe17194b370b2_translated.bpmn and saved to ./output/processed_Aufgabe_1_5b60340cf441488b9f9fe17194b370b2_translated.bpmn.txt
# Processed Aufgabe_3_-_Regressnahme_85ba47b6b06c429da81ed4723f0ebe5e_translated.bpmn and saved to ./output/processed_Aufgabe_3_-_Regressnahme_85ba47b6b06c429da81ed4723f0ebe5e_translated.bpmn.txt
# Processed Aufgabe_3_6c08c1c8f6a54c43ae18c89d07016d0f_translated.bpmn and saved to ./output/processed_Aufgabe_3_6c08c1c8f6a54c43ae18c89d07016d0f_translated.bpmn.txt
# Processed Aufgabe_3_79db7a163b68425487ecc080bffd257b_translated.bpmn and saved to ./output/processed_Aufgabe_3_79db7a163b68425487ecc080bffd257b_translated.bpmn.txt
# Processed Aufgabe_7_-_Schufascoring_112537f7ba20411196e8c58da704a8a5_translated.bpmn and saved to ./output/processed_Aufgabe_7_-_Schufascoring_112537f7ba20411196e8c58da704a8a5_translated.bpmn.txt
# Processed Aufgabe_7_e18e5f3c92fd4c298cc56ae757499cb9_translated.bpmn and saved to ./output/processed_Aufgabe_7_e18e5f3c92fd4c298cc56ae757499cb9_translated.bpmn.txt
# Processed Aufgabe_7_Schufascoring_c612cc8ea5584028a549329658ff9811_translated.bpmn and saved to ./output/processed_Aufgabe_7_Schufascoring_c612cc8ea5584028a549329658ff9811_translated.bpmn.txt
# Processed Aufgabe_8_5bdb6c217e2643e79d3ed434dbcae86e_translated.bpmn and saved to ./output/processed_Aufgabe_8_5bdb6c217e2643e79d3ed434dbcae86e_translated.bpmn.txt
# Processed Aufgabe_8_b459e598bbea479cbe49c5d84a6d43dd_translated.bpmn and saved to ./output/processed_Aufgabe_8_b459e598bbea479cbe49c5d84a6d43dd_translated.bpmn.txt
# Processed Beispiel_3_restaurant_d1d1df576d3144e3b2a9d4d46f989706_translated.bpmn and saved to ./output/processed_Beispiel_3_restaurant_d1d1df576d3144e3b2a9d4d46f989706_translated.bpmn.txt
# Processed Bestellprozess_beddf31ae83240119a346ca7ba0be591_translated.bpmn and saved to ./output/processed_Bestellprozess_beddf31ae83240119a346ca7ba0be591_translated.bpmn.txt
# Processed BPMN__bung7_cd9a8d06b62c46ac836893bc8b518c7f_translated.bpmn and saved to ./output/processed_BPMN__bung7_cd9a8d06b62c46ac836893bc8b518c7f_translated.bpmn.txt
# Processed BPMN__bung8_0edf9a98f128438ea799cbcfd5d1006a_translated.bpmn and saved to ./output/processed_BPMN__bung8_0edf9a98f128438ea799cbcfd5d1006a_translated.bpmn.txt
# Processed Demo_Signavio_5b48b8fee22c4ea7ae2ef4599511dc17_translated.bpmn and saved to ./output/processed_Demo_Signavio_5b48b8fee22c4ea7ae2ef4599511dc17_translated.bpmn.txt
# Processed Demo_Signavio_797994f4f44a4fe19973343fef6381c3_translated.bpmn and saved to ./output/processed_Demo_Signavio_797994f4f44a4fe19973343fef6381c3_translated.bpmn.txt
# Processed diagram_2__b71135062c944fefa4b8ad30f78b61d2_translated.bpmn and saved to ./output/processed_diagram_2__b71135062c944fefa4b8ad30f78b61d2_translated.bpmn.txt
# Processed erster_Prozess_0eed78ea0d5f44f2bcf0a4d0c4e19035_translated.bpmn and saved to ./output/processed_erster_Prozess_0eed78ea0d5f44f2bcf0a4d0c4e19035_translated.bpmn.txt
# Processed Essen_bestellen_6ede749721d3431b845d460dc5e6e35f_translated.bpmn and saved to ./output/processed_Essen_bestellen_6ede749721d3431b845d460dc5e6e35f_translated.bpmn.txt
# Processed Gruppe_1_129b3edff83046fbbb5fe0197edcbe7e_translated.bpmn and saved to ./output/processed_Gruppe_1_129b3edff83046fbbb5fe0197edcbe7e_translated.bpmn.txt
# Processed Gruppe_2_87b19c8d212b4b58a8e7ba45934e05d3_translated.bpmn and saved to ./output/processed_Gruppe_2_87b19c8d212b4b58a8e7ba45934e05d3_translated.bpmn.txt
# Processed Gruppe_3_6e2af121e6b3468b9405c89b1df90445_translated.bpmn and saved to ./output/processed_Gruppe_3_6e2af121e6b3468b9405c89b1df90445_translated.bpmn.txt
# Processed Kreditvergabe_2d15761958d94397b11086cb65c92a0f_translated.bpmn and saved to ./output/processed_Kreditvergabe_2d15761958d94397b11086cb65c92a0f_translated.bpmn.txt
# Processed Kreditvergabe_Schufascoring_2fc73ea29913423cbd8b8e41278e9f0b_translated.bpmn and saved to ./output/processed_Kreditvergabe_Schufascoring_2fc73ea29913423cbd8b8e41278e9f0b_translated.bpmn.txt
# Processed Mc_Doof_e1fe50a7813f41268db660af8021604e_translated.bpmn and saved to ./output/processed_Mc_Doof_e1fe50a7813f41268db660af8021604e_translated.bpmn.txt
# Processed Neuer_Prozess4_1920a3905ccc41f8a8d64b451d85ad42_translated.bpmn and saved to ./output/processed_Neuer_Prozess4_1920a3905ccc41f8a8d64b451d85ad42_translated.bpmn.txt
# Processed Neuer_Prozess7_fde2374fe2f842b7a1da9c9a02ce2a93_translated.bpmn and saved to ./output/processed_Neuer_Prozess7_fde2374fe2f842b7a1da9c9a02ce2a93_translated.bpmn.txt
# Processed Neuer_Prozess_093ca23ed382481ca97f7ff76d859e2c_translated.bpmn and saved to ./output/processed_Neuer_Prozess_093ca23ed382481ca97f7ff76d859e2c_translated.bpmn.txt
# Processed Neuer_Prozess_1257630bfb5d4ca5979900aed5cb8f13_translated.bpmn and saved to ./output/processed_Neuer_Prozess_1257630bfb5d4ca5979900aed5cb8f13_translated.bpmn.txt
# Processed Neuer_Prozess_131b84011e18477793620aa072d82a5f_translated.bpmn and saved to ./output/processed_Neuer_Prozess_131b84011e18477793620aa072d82a5f_translated.bpmn.txt
# Processed Neuer_Prozess_1627e1d15734446cb204230582ca35d6_translated.bpmn and saved to ./output/processed_Neuer_Prozess_1627e1d15734446cb204230582ca35d6_translated.bpmn.txt
# Processed Neuer_Prozess_2593c913e86842f592bd73737b301369_translated.bpmn and saved to ./output/processed_Neuer_Prozess_2593c913e86842f592bd73737b301369_translated.bpmn.txt
# Processed Neuer_Prozess_38bdce6c4e9746a8833a6de718f6ca9a_translated.bpmn and saved to ./output/processed_Neuer_Prozess_38bdce6c4e9746a8833a6de718f6ca9a_translated.bpmn.txt
# Processed Neuer_Prozess_4331176882024b8cbfb4744a3afd4fdf_translated.bpmn and saved to ./output/processed_Neuer_Prozess_4331176882024b8cbfb4744a3afd4fdf_translated.bpmn.txt
# Processed Neuer_Prozess_55d0873f5076426bbadfa972a1941b4f_translated.bpmn and saved to ./output/processed_Neuer_Prozess_55d0873f5076426bbadfa972a1941b4f_translated.bpmn.txt
# Processed Neuer_Prozess_721f92d85d6244f1b2f2015f2d44caf4_translated.bpmn and saved to ./output/processed_Neuer_Prozess_721f92d85d6244f1b2f2015f2d44caf4_translated.bpmn.txt
# Processed Neuer_Prozess_7d389fcd90c04b19892721e639dd2714_translated.bpmn and saved to ./output/processed_Neuer_Prozess_7d389fcd90c04b19892721e639dd2714_translated.bpmn.txt
# Processed Neuer_Prozess_95c331ed5d8a4073a7661a7231b4bee3_translated.bpmn and saved to ./output/processed_Neuer_Prozess_95c331ed5d8a4073a7661a7231b4bee3_translated.bpmn.txt
# Processed Neuer_Prozess_a7e30e0867cb472e8b3c1e87f00e00bc_translated.bpmn and saved to ./output/processed_Neuer_Prozess_a7e30e0867cb472e8b3c1e87f00e00bc_translated.bpmn.txt
# Processed Neuer_Prozess_b6a9732ef2874d58bbd70a96b0244a68_translated.bpmn and saved to ./output/processed_Neuer_Prozess_b6a9732ef2874d58bbd70a96b0244a68_translated.bpmn.txt
# Processed Neuer_Prozess_bf8f68238ff4425590cc3f5ba96b8c65_translated.bpmn and saved to ./output/processed_Neuer_Prozess_bf8f68238ff4425590cc3f5ba96b8c65_translated.bpmn.txt
# Processed Neuer_Prozess_c3a474cc6e414e249c747a31f530dcbe_translated.bpmn and saved to ./output/processed_Neuer_Prozess_c3a474cc6e414e249c747a31f530dcbe_translated.bpmn.txt
# Processed Neuer_Prozess_dcae3792e19348208aae308ca6baeaf3_translated.bpmn and saved to ./output/processed_Neuer_Prozess_dcae3792e19348208aae308ca6baeaf3_translated.bpmn.txt
# Processed Neuer_Prozess_e83dddd2bd4a4a058e7101ba38af18f9_translated.bpmn and saved to ./output/processed_Neuer_Prozess_e83dddd2bd4a4a058e7101ba38af18f9_translated.bpmn.txt
# Processed New_Process__bung_3_825e5707085c4cdfa76d23328e62c36f_translated.bpmn and saved to ./output/processed_New_Process__bung_3_825e5707085c4cdfa76d23328e62c36f_translated.bpmn.txt
# Processed Regressannahme_305ef4e463504378b2e2bd905ced7950_translated.bpmn and saved to ./output/processed_Regressannahme_305ef4e463504378b2e2bd905ced7950_translated.bpmn.txt
# Processed Regressanspruch_an_VN_7375f350582640cdb87abd9d9ff5d875_translated.bpmn and saved to ./output/processed_Regressanspruch_an_VN_7375f350582640cdb87abd9d9ff5d875_translated.bpmn.txt
# Processed Regressfall_9b6bf62771ab4e34a90047b19fc9077a_translated.bpmn and saved to ./output/processed_Regressfall_9b6bf62771ab4e34a90047b19fc9077a_translated.bpmn.txt
# Processed Regressforderung_388ac24aed634cc284cf38ffe13e33c7_translated.bpmn and saved to ./output/processed_Regressforderung_388ac24aed634cc284cf38ffe13e33c7_translated.bpmn.txt
# Processed Regressnahmen_e6fd2b6da6774634ab02d6515a9a4929_translated.bpmn and saved to ./output/processed_Regressnahmen_e6fd2b6da6774634ab02d6515a9a4929_translated.bpmn.txt
# Processed Regressnahme_-__bung_2_352297699a4c42b499dce3d88d788170_translated.bpmn and saved to ./output/processed_Regressnahme_-__bung_2_352297699a4c42b499dce3d88d788170_translated.bpmn.txt
# Processed Regressnahme_0429bddca9594c3c98975876612bb0ad_translated.bpmn and saved to ./output/processed_Regressnahme_0429bddca9594c3c98975876612bb0ad_translated.bpmn.txt
# Processed Regressnahme_04e22456cc9b4a6db6c187d983e45f53_translated.bpmn and saved to ./output/processed_Regressnahme_04e22456cc9b4a6db6c187d983e45f53_translated.bpmn.txt
# Processed Regressnahme_0583e805ab5148668d6eff2ec4230928_translated.bpmn and saved to ./output/processed_Regressnahme_0583e805ab5148668d6eff2ec4230928_translated.bpmn.txt
# Processed Regressnahme_084e5fb09cce4df886e2ff9c5323498f_translated.bpmn and saved to ./output/processed_Regressnahme_084e5fb09cce4df886e2ff9c5323498f_translated.bpmn.txt
# Processed Regressnahme_08795d591f9c4913917e8c9a11a1ddd0_translated.bpmn and saved to ./output/processed_Regressnahme_08795d591f9c4913917e8c9a11a1ddd0_translated.bpmn.txt
# Processed Regressnahme_0969d965707946dfb928feb6eba41a46_translated.bpmn and saved to ./output/processed_Regressnahme_0969d965707946dfb928feb6eba41a46_translated.bpmn.txt
# Processed Regressnahme_0a89ef9d86084dcc96ba63f71f39f0f2_translated.bpmn and saved to ./output/processed_Regressnahme_0a89ef9d86084dcc96ba63f71f39f0f2_translated.bpmn.txt
# Processed Regressnahme_0aad426b5f3347f695af87588489460b_translated.bpmn and saved to ./output/processed_Regressnahme_0aad426b5f3347f695af87588489460b_translated.bpmn.txt
# Processed Regressnahme_0d921ac6a7f6406aad8f0c1d5b7f8f49_translated.bpmn and saved to ./output/processed_Regressnahme_0d921ac6a7f6406aad8f0c1d5b7f8f49_translated.bpmn.txt
# Processed Regressnahme_0dd4ea15cdd842f3821ce0c79be07f70_translated.bpmn and saved to ./output/processed_Regressnahme_0dd4ea15cdd842f3821ce0c79be07f70_translated.bpmn.txt
# Processed Regressnahme_0df9a5618e1648bdb44bb5df13af73a7_translated.bpmn and saved to ./output/processed_Regressnahme_0df9a5618e1648bdb44bb5df13af73a7_translated.bpmn.txt
# Processed Regressnahme_0f31624f95ad4f1fb3671b72b1beefff_translated.bpmn and saved to ./output/processed_Regressnahme_0f31624f95ad4f1fb3671b72b1beefff_translated.bpmn.txt
# Processed Regressnahme_104eb27567b54ddba438a16fe94a0fa6_translated.bpmn and saved to ./output/processed_Regressnahme_104eb27567b54ddba438a16fe94a0fa6_translated.bpmn.txt
# Processed Regressnahme_10646063c9af436cbd1087b0b12a460d_translated.bpmn and saved to ./output/processed_Regressnahme_10646063c9af436cbd1087b0b12a460d_translated.bpmn.txt
# Processed Regressnahme_137682c6bc164e8e848ebd537e4c209f_translated.bpmn and saved to ./output/processed_Regressnahme_137682c6bc164e8e848ebd537e4c209f_translated.bpmn.txt
# Processed Regressnahme_148ab4debdfd4314a3cac0928c325db2_translated.bpmn and saved to ./output/processed_Regressnahme_148ab4debdfd4314a3cac0928c325db2_translated.bpmn.txt
# Processed Regressnahme_17c594259b9d49acbf73b5eaf9c4be3c_translated.bpmn and saved to ./output/processed_Regressnahme_17c594259b9d49acbf73b5eaf9c4be3c_translated.bpmn.txt
# Processed Regressnahme_183b656fd4d8429b9b20a5ebc5edb113_translated.bpmn and saved to ./output/processed_Regressnahme_183b656fd4d8429b9b20a5ebc5edb113_translated.bpmn.txt
# Processed Regressnahme_18dc6f50cd2d453cbaa8560ec5e4076c_translated.bpmn and saved to ./output/processed_Regressnahme_18dc6f50cd2d453cbaa8560ec5e4076c_translated.bpmn.txt
# Processed Regressnahme_192623ae4d5948b2a6a32c11acfc0116_translated.bpmn and saved to ./output/processed_Regressnahme_192623ae4d5948b2a6a32c11acfc0116_translated.bpmn.txt
# Processed regressnahme_1967fa861dbe41e7bba58f8ec5cbd428_translated.bpmn and saved to ./output/processed_regressnahme_1967fa861dbe41e7bba58f8ec5cbd428_translated.bpmn.txt
# Processed Regressnahme_1b55d633d7cc4d42a686f4d0ec5a8b0e_translated.bpmn and saved to ./output/processed_Regressnahme_1b55d633d7cc4d42a686f4d0ec5a8b0e_translated.bpmn.txt
# Processed regressnahme_1c0b08eeb8c04106976ed13f7996d3c9_translated.bpmn and saved to ./output/processed_regressnahme_1c0b08eeb8c04106976ed13f7996d3c9_translated.bpmn.txt
# Processed Regressnahme_1c3ae984889c431f8eedd17dd513b1b1_translated.bpmn and saved to ./output/processed_Regressnahme_1c3ae984889c431f8eedd17dd513b1b1_translated.bpmn.txt
# Processed Regressnahme_1ccd8804ab36485d91b82ad664339087_translated.bpmn and saved to ./output/processed_Regressnahme_1ccd8804ab36485d91b82ad664339087_translated.bpmn.txt
# Processed Regressnahme_1_aa5dbb0346fc48f69d9ccfd87915e3c6_translated.bpmn and saved to ./output/processed_Regressnahme_1_aa5dbb0346fc48f69d9ccfd87915e3c6_translated.bpmn.txt
# Processed Regressnahme_210ac5b887c64ed1bb293dc004f021c4_translated.bpmn and saved to ./output/processed_Regressnahme_210ac5b887c64ed1bb293dc004f021c4_translated.bpmn.txt
# Processed Regressnahme_237ebd3eed3f43f4a150d26a7f14e33c_translated.bpmn and saved to ./output/processed_Regressnahme_237ebd3eed3f43f4a150d26a7f14e33c_translated.bpmn.txt
# Processed Regressnahme_23d5bee1ee6948de9fecd3b3a046ba70_translated.bpmn and saved to ./output/processed_Regressnahme_23d5bee1ee6948de9fecd3b3a046ba70_translated.bpmn.txt
# Processed Regressnahme_255084fddba344cfa4a9bb8914f3d7d0_translated.bpmn and saved to ./output/processed_Regressnahme_255084fddba344cfa4a9bb8914f3d7d0_translated.bpmn.txt
# Processed Regressnahme_26094fe86fac4aff91056273f4cd5cd0_translated.bpmn and saved to ./output/processed_Regressnahme_26094fe86fac4aff91056273f4cd5cd0_translated.bpmn.txt
# Processed regressnahme_275260aca4634454ae2e3415af1abfc5_translated.bpmn and saved to ./output/processed_regressnahme_275260aca4634454ae2e3415af1abfc5_translated.bpmn.txt
# Processed Regressnahme_28aaec42e24e4bccb103d8877b3d1825_translated.bpmn and saved to ./output/processed_Regressnahme_28aaec42e24e4bccb103d8877b3d1825_translated.bpmn.txt
# Processed Regressnahme_2b4cbdf2f56f426d9945090196b95d77_translated.bpmn and saved to ./output/processed_Regressnahme_2b4cbdf2f56f426d9945090196b95d77_translated.bpmn.txt
# Processed Regressnahme_2d2800e8b13146e1bfb20b929b8701a6_translated.bpmn and saved to ./output/processed_Regressnahme_2d2800e8b13146e1bfb20b929b8701a6_translated.bpmn.txt
# Processed Regressnahme_2d59cf1b98e44fdaa2b04f3cadb46c2f_translated.bpmn and saved to ./output/processed_Regressnahme_2d59cf1b98e44fdaa2b04f3cadb46c2f_translated.bpmn.txt
# Processed Regressnahme_2da8d446d5674887b25409e23457e396_translated.bpmn and saved to ./output/processed_Regressnahme_2da8d446d5674887b25409e23457e396_translated.bpmn.txt
# Processed Regressnahme_2ed2b0beabde452b95f12fb10d05dc8a_translated.bpmn and saved to ./output/processed_Regressnahme_2ed2b0beabde452b95f12fb10d05dc8a_translated.bpmn.txt
# Processed Regressnahme_2ef120ea74514f1b95473fc444fdf6e7_translated.bpmn and saved to ./output/processed_Regressnahme_2ef120ea74514f1b95473fc444fdf6e7_translated.bpmn.txt
# Processed Regressnahme_2f756601390246bab9a048350590d814_translated.bpmn and saved to ./output/processed_Regressnahme_2f756601390246bab9a048350590d814_translated.bpmn.txt
# Processed Regressnahme_30285b2a0d1d4d248b0e0076e18bb1b0_translated.bpmn and saved to ./output/processed_Regressnahme_30285b2a0d1d4d248b0e0076e18bb1b0_translated.bpmn.txt
# Processed Regressnahme_312955416b3e428997bd7266ca3a97d8_translated.bpmn and saved to ./output/processed_Regressnahme_312955416b3e428997bd7266ca3a97d8_translated.bpmn.txt
# Processed Regressnahme_32e6d01a5f134985b51cbc384c42a74f_translated.bpmn and saved to ./output/processed_Regressnahme_32e6d01a5f134985b51cbc384c42a74f_translated.bpmn.txt
# Processed Regressnahme_3317b3adb1944a20ad7a820050d24652_translated.bpmn and saved to ./output/processed_Regressnahme_3317b3adb1944a20ad7a820050d24652_translated.bpmn.txt
# Processed Regressnahme_3394d5fb1936435e931e3e9905819a84_translated.bpmn and saved to ./output/processed_Regressnahme_3394d5fb1936435e931e3e9905819a84_translated.bpmn.txt
# Processed Regressnahme_3650d332238c43659d599dd134c79e97_translated.bpmn and saved to ./output/processed_Regressnahme_3650d332238c43659d599dd134c79e97_translated.bpmn.txt
# Processed Regressnahme_3943c125370e434eb53d3a3d9a6107dc_translated.bpmn and saved to ./output/processed_Regressnahme_3943c125370e434eb53d3a3d9a6107dc_translated.bpmn.txt
# Processed Regressnahme_3bce6c414bcb4dc7a37e563dc1d00436_translated.bpmn and saved to ./output/processed_Regressnahme_3bce6c414bcb4dc7a37e563dc1d00436_translated.bpmn.txt
# Processed Regressnahme_406af9c07df14a80918bf3659387ff73_translated.bpmn and saved to ./output/processed_Regressnahme_406af9c07df14a80918bf3659387ff73_translated.bpmn.txt
# Processed Regressnahme_42d03ac7d75c4eeb860b7d21c182d6f8_translated.bpmn and saved to ./output/processed_Regressnahme_42d03ac7d75c4eeb860b7d21c182d6f8_translated.bpmn.txt
# Processed Regressnahme_43dfeffa9bed4143935a716cbd8f05a6_translated.bpmn and saved to ./output/processed_Regressnahme_43dfeffa9bed4143935a716cbd8f05a6_translated.bpmn.txt
# Processed Regressnahme_44ca7294274942ca8ef0a9e662c599c5_translated.bpmn and saved to ./output/processed_Regressnahme_44ca7294274942ca8ef0a9e662c599c5_translated.bpmn.txt
# Processed Regressnahme_468e54adf176493984d83b126aab53c1_translated.bpmn and saved to ./output/processed_Regressnahme_468e54adf176493984d83b126aab53c1_translated.bpmn.txt
# Processed Regressnahme_4691ef2caaec4005ae883438713a017b_translated.bpmn and saved to ./output/processed_Regressnahme_4691ef2caaec4005ae883438713a017b_translated.bpmn.txt
# Processed Regressnahme_4700111829034d00b9a062b32d2c1f7a_translated.bpmn and saved to ./output/processed_Regressnahme_4700111829034d00b9a062b32d2c1f7a_translated.bpmn.txt
# Processed Regressnahme_479b19802fe54203a7bbeba30651936e_translated.bpmn and saved to ./output/processed_Regressnahme_479b19802fe54203a7bbeba30651936e_translated.bpmn.txt
# Processed Regressnahme_47c3bae8bd9a41618785089ce76f1bed_translated.bpmn and saved to ./output/processed_Regressnahme_47c3bae8bd9a41618785089ce76f1bed_translated.bpmn.txt
# Processed Regressnahme_480d50081fb045fe85284b407762c5ff_translated.bpmn and saved to ./output/processed_Regressnahme_480d50081fb045fe85284b407762c5ff_translated.bpmn.txt
# Processed regressnahme_492d4b17d25d4b4da4f377024ae1aab8_translated.bpmn and saved to ./output/processed_regressnahme_492d4b17d25d4b4da4f377024ae1aab8_translated.bpmn.txt
# Processed Regressnahme_49e03a3248ae4e5cb988c06f66c453a8_translated.bpmn and saved to ./output/processed_Regressnahme_49e03a3248ae4e5cb988c06f66c453a8_translated.bpmn.txt
# Processed Regressnahme_4a19ddb7a5be40159e45183e4aa93dc2_translated.bpmn and saved to ./output/processed_Regressnahme_4a19ddb7a5be40159e45183e4aa93dc2_translated.bpmn.txt
# Processed Regressnahme_4c05b787336a4fd3a39498a3975ad546_translated.bpmn and saved to ./output/processed_Regressnahme_4c05b787336a4fd3a39498a3975ad546_translated.bpmn.txt
# Processed Regressnahme_4d0439a619cd4ba697d0d9c45c095238_translated.bpmn and saved to ./output/processed_Regressnahme_4d0439a619cd4ba697d0d9c45c095238_translated.bpmn.txt
# Processed Regressnahme_4d1f37dc21ad47cda3df8ed136e9ed74_translated.bpmn and saved to ./output/processed_Regressnahme_4d1f37dc21ad47cda3df8ed136e9ed74_translated.bpmn.txt
# Processed Regressnahme_4d2a6a31159740b6badee82db59c4c5a_translated.bpmn and saved to ./output/processed_Regressnahme_4d2a6a31159740b6badee82db59c4c5a_translated.bpmn.txt
# Processed Regressnahme_4d2e1c3e48454516ae963ab7a7827407_translated.bpmn and saved to ./output/processed_Regressnahme_4d2e1c3e48454516ae963ab7a7827407_translated.bpmn.txt
# Processed Regressnahme_4d309e23185f40b49a87c72aeb1a8245_translated.bpmn and saved to ./output/processed_Regressnahme_4d309e23185f40b49a87c72aeb1a8245_translated.bpmn.txt
# Processed Regressnahme_4de330dbd25c4fb1b65f0eb80b9b1a9b_translated.bpmn and saved to ./output/processed_Regressnahme_4de330dbd25c4fb1b65f0eb80b9b1a9b_translated.bpmn.txt
# Processed Regressnahme_4e35b33cbe374224be553fbc1ea2bfe9_translated.bpmn and saved to ./output/processed_Regressnahme_4e35b33cbe374224be553fbc1ea2bfe9_translated.bpmn.txt
# Processed Regressnahme_4f3096557c0f49398b5c8d7ebf1bdd6a_translated.bpmn and saved to ./output/processed_Regressnahme_4f3096557c0f49398b5c8d7ebf1bdd6a_translated.bpmn.txt
# Processed Regressnahme_4f9f95019347422f9b866be699822dd4_translated.bpmn and saved to ./output/processed_Regressnahme_4f9f95019347422f9b866be699822dd4_translated.bpmn.txt
# Processed Regressnahme_501b6af044a6420b93d01771810437c1_translated.bpmn and saved to ./output/processed_Regressnahme_501b6af044a6420b93d01771810437c1_translated.bpmn.txt
# Processed Regressnahme_51c11363414a4ababe717b4d768083f0_translated.bpmn and saved to ./output/processed_Regressnahme_51c11363414a4ababe717b4d768083f0_translated.bpmn.txt
# Processed Regressnahme_520ab2200e1b4128a15f3d67dbb6e208_translated.bpmn and saved to ./output/processed_Regressnahme_520ab2200e1b4128a15f3d67dbb6e208_translated.bpmn.txt
# Processed Regressnahme_53399a67d93d4731b93ffa14ed193dc4_translated.bpmn and saved to ./output/processed_Regressnahme_53399a67d93d4731b93ffa14ed193dc4_translated.bpmn.txt
# Processed Regressnahme_54e854bdcbf248a698557817c51b997a_translated.bpmn and saved to ./output/processed_Regressnahme_54e854bdcbf248a698557817c51b997a_translated.bpmn.txt
# Processed Regressnahme_56c630e02c69460cab3721ebb85ddb88_translated.bpmn and saved to ./output/processed_Regressnahme_56c630e02c69460cab3721ebb85ddb88_translated.bpmn.txt
# Processed Regressnahme_58d9c23a6d4b4e438c556d428d2197da_translated.bpmn and saved to ./output/processed_Regressnahme_58d9c23a6d4b4e438c556d428d2197da_translated.bpmn.txt
# Processed Regressnahme_5aa86920e53946a59e8e7be608e492a0_translated.bpmn and saved to ./output/processed_Regressnahme_5aa86920e53946a59e8e7be608e492a0_translated.bpmn.txt
# Processed Regressnahme_5cf5dde691264215be2a2f1c778f7077_translated.bpmn and saved to ./output/processed_Regressnahme_5cf5dde691264215be2a2f1c778f7077_translated.bpmn.txt
# Processed Regressnahme_5d0fc4643b2b47778d03165e7e94db67_translated.bpmn and saved to ./output/processed_Regressnahme_5d0fc4643b2b47778d03165e7e94db67_translated.bpmn.txt
# Processed Regressnahme_5d51b90888c4435e8d8440e884d2c560_translated.bpmn and saved to ./output/processed_Regressnahme_5d51b90888c4435e8d8440e884d2c560_translated.bpmn.txt
# Processed Regressnahme_5d581aa918514a47b58a5ebc1425fe8f_translated.bpmn and saved to ./output/processed_Regressnahme_5d581aa918514a47b58a5ebc1425fe8f_translated.bpmn.txt
# Processed Regressnahme_6029d1bf39ca487f9a0b3af4780eee15_translated.bpmn and saved to ./output/processed_Regressnahme_6029d1bf39ca487f9a0b3af4780eee15_translated.bpmn.txt
# Processed Regressnahme_6197ac6eb650404189f8bb1d5317caef_translated.bpmn and saved to ./output/processed_Regressnahme_6197ac6eb650404189f8bb1d5317caef_translated.bpmn.txt
# Processed Regressnahme_61d7f1bdde3e473382a263ddbb39baaf_translated.bpmn and saved to ./output/processed_Regressnahme_61d7f1bdde3e473382a263ddbb39baaf_translated.bpmn.txt
# Processed Regressnahme_64ef9984c12b4a36bd74c8ca035b864e_translated.bpmn and saved to ./output/processed_Regressnahme_64ef9984c12b4a36bd74c8ca035b864e_translated.bpmn.txt
# Processed Regressnahme_66f2ff60abc048bba4973629ae7587f8_translated.bpmn and saved to ./output/processed_Regressnahme_66f2ff60abc048bba4973629ae7587f8_translated.bpmn.txt
# Processed Regressnahme_672583891d594a859f8b1401febd8078_translated.bpmn and saved to ./output/processed_Regressnahme_672583891d594a859f8b1401febd8078_translated.bpmn.txt
# Processed Regressnahme_69a83f62f48241b28cd3849b635d3410_translated.bpmn and saved to ./output/processed_Regressnahme_69a83f62f48241b28cd3849b635d3410_translated.bpmn.txt
# Processed regressnahme_6a4823bc8d464b2b97fb6228b4eb81c5_translated.bpmn and saved to ./output/processed_regressnahme_6a4823bc8d464b2b97fb6228b4eb81c5_translated.bpmn.txt
# Processed Regressnahme_6af78a431c4342ed8174b31b5d7402ee_translated.bpmn and saved to ./output/processed_Regressnahme_6af78a431c4342ed8174b31b5d7402ee_translated.bpmn.txt
# Processed Regressnahme_6c815bbc39ef42c2966d070b8cfb2e9f_translated.bpmn and saved to ./output/processed_Regressnahme_6c815bbc39ef42c2966d070b8cfb2e9f_translated.bpmn.txt
# Processed Regressnahme_6cd94bed0779415887c3748418a2fb43_translated.bpmn and saved to ./output/processed_Regressnahme_6cd94bed0779415887c3748418a2fb43_translated.bpmn.txt
# Processed Regressnahme_6eff00995ae546048fbafe0a440ba929_translated.bpmn and saved to ./output/processed_Regressnahme_6eff00995ae546048fbafe0a440ba929_translated.bpmn.txt
# Processed Regressnahme_70a1d349eaec43c59185a2865e1cccbe_translated.bpmn and saved to ./output/processed_Regressnahme_70a1d349eaec43c59185a2865e1cccbe_translated.bpmn.txt
# Processed Regressnahme_72ab7b22ab6542beb6d9c4e22b549e6b_translated.bpmn and saved to ./output/processed_Regressnahme_72ab7b22ab6542beb6d9c4e22b549e6b_translated.bpmn.txt
# Processed Regressnahme_72bb4ab20bd54fdca9f4f8bfce4bca15_translated.bpmn and saved to ./output/processed_Regressnahme_72bb4ab20bd54fdca9f4f8bfce4bca15_translated.bpmn.txt
# Processed Regressnahme_72bd15ea8db74505a99c1b23fc9824d6_translated.bpmn and saved to ./output/processed_Regressnahme_72bd15ea8db74505a99c1b23fc9824d6_translated.bpmn.txt
# Processed Regressnahme_7319d4ce653a49769f14206ee29e07ae_translated.bpmn and saved to ./output/processed_Regressnahme_7319d4ce653a49769f14206ee29e07ae_translated.bpmn.txt
# Processed Regressnahme_7343af3eefbb4d86ab82dbf7bac13f52_translated.bpmn and saved to ./output/processed_Regressnahme_7343af3eefbb4d86ab82dbf7bac13f52_translated.bpmn.txt
# Processed Regressnahme_750510de0ec84b39b5c85edcf56dd294_translated.bpmn and saved to ./output/processed_Regressnahme_750510de0ec84b39b5c85edcf56dd294_translated.bpmn.txt
# Processed Regressnahme_76248b3a37ea445fa6ce4448d84b904b_translated.bpmn and saved to ./output/processed_Regressnahme_76248b3a37ea445fa6ce4448d84b904b_translated.bpmn.txt
# Processed Regressnahme_77c54ad0621743b68dd532d070060133_translated.bpmn and saved to ./output/processed_Regressnahme_77c54ad0621743b68dd532d070060133_translated.bpmn.txt
# Processed Regressnahme_787b677dd40a40eab95d0f5089cdd3e1_translated.bpmn and saved to ./output/processed_Regressnahme_787b677dd40a40eab95d0f5089cdd3e1_translated.bpmn.txt
# Processed Regressnahme_7897468a938d492c976b3ee7af58bfe7_translated.bpmn and saved to ./output/processed_Regressnahme_7897468a938d492c976b3ee7af58bfe7_translated.bpmn.txt
# Processed Regressnahme_78f367e6a0b5459a9a9ae729cfc459c2_translated.bpmn and saved to ./output/processed_Regressnahme_78f367e6a0b5459a9a9ae729cfc459c2_translated.bpmn.txt
# Processed Regressnahme_794a0fcd08aa477988daa1b163b159da_translated.bpmn and saved to ./output/processed_Regressnahme_794a0fcd08aa477988daa1b163b159da_translated.bpmn.txt
# Processed Regressnahme_794f43fe6e4f4139bb6035e561dc3596_translated.bpmn and saved to ./output/processed_Regressnahme_794f43fe6e4f4139bb6035e561dc3596_translated.bpmn.txt
# Processed Regressnahme_7996d3b901f2433fabdfa438d8e9efb0_translated.bpmn and saved to ./output/processed_Regressnahme_7996d3b901f2433fabdfa438d8e9efb0_translated.bpmn.txt
# Processed Regressnahme_7cc9cea1814c4fa5948bb5304c5c6bcc_translated.bpmn and saved to ./output/processed_Regressnahme_7cc9cea1814c4fa5948bb5304c5c6bcc_translated.bpmn.txt
# Processed Regressnahme_7cff75aa2ba148f790d60a0ea241c371_translated.bpmn and saved to ./output/processed_Regressnahme_7cff75aa2ba148f790d60a0ea241c371_translated.bpmn.txt
# Processed Regressnahme_7e637100373a4a8b92b8f0160955eafc_translated.bpmn and saved to ./output/processed_Regressnahme_7e637100373a4a8b92b8f0160955eafc_translated.bpmn.txt
# Processed Regressnahme_7ebe7cf4238943f29e7fb8921bbcbad3_translated.bpmn and saved to ./output/processed_Regressnahme_7ebe7cf4238943f29e7fb8921bbcbad3_translated.bpmn.txt
# Processed Regressnahme_7efb92f4388c47fcb4c6c50ebd91a0d0_translated.bpmn and saved to ./output/processed_Regressnahme_7efb92f4388c47fcb4c6c50ebd91a0d0_translated.bpmn.txt
# Processed Regressnahme_80303c59af0e464f866c73fd502789b7_translated.bpmn and saved to ./output/processed_Regressnahme_80303c59af0e464f866c73fd502789b7_translated.bpmn.txt
# Processed Regressnahme_803167aab0074db9add2fc6ce5ecf989_translated.bpmn and saved to ./output/processed_Regressnahme_803167aab0074db9add2fc6ce5ecf989_translated.bpmn.txt
# Processed regressnahme_81c4d12d26af44aea8756df2ec87896a_translated.bpmn and saved to ./output/processed_regressnahme_81c4d12d26af44aea8756df2ec87896a_translated.bpmn.txt
# Processed Regressnahme_824903299311495baa896b3c9519fbb8_translated.bpmn and saved to ./output/processed_Regressnahme_824903299311495baa896b3c9519fbb8_translated.bpmn.txt
# Processed regressnahme_82826cdd21c24771b695366321bb7cae_translated.bpmn and saved to ./output/processed_regressnahme_82826cdd21c24771b695366321bb7cae_translated.bpmn.txt
# Processed Regressnahme_84c0b4c15546421aa2c8859e57d876f7_translated.bpmn and saved to ./output/processed_Regressnahme_84c0b4c15546421aa2c8859e57d876f7_translated.bpmn.txt
# Processed Regressnahme_85857ecbdb124429b8721044febb0c62_translated.bpmn and saved to ./output/processed_Regressnahme_85857ecbdb124429b8721044febb0c62_translated.bpmn.txt
# Processed Regressnahme_875326851b714f01ae83e66c4ffc1e76_translated.bpmn and saved to ./output/processed_Regressnahme_875326851b714f01ae83e66c4ffc1e76_translated.bpmn.txt
# Processed Regressnahme_8764bfa832fd4f118ade0381df3732ae_translated.bpmn and saved to ./output/processed_Regressnahme_8764bfa832fd4f118ade0381df3732ae_translated.bpmn.txt
# Processed Regressnahme_881561a3635c42679c9b0ce16df41139_translated.bpmn and saved to ./output/processed_Regressnahme_881561a3635c42679c9b0ce16df41139_translated.bpmn.txt
# Processed Regressnahme_88dea7997e3d4f4cb9007b2077b3422f_translated.bpmn and saved to ./output/processed_Regressnahme_88dea7997e3d4f4cb9007b2077b3422f_translated.bpmn.txt
# Processed Regressnahme_8907c8bc6a834e71a0ffcf68211b711f_translated.bpmn and saved to ./output/processed_Regressnahme_8907c8bc6a834e71a0ffcf68211b711f_translated.bpmn.txt
# Processed Regressnahme_8acc7092c0ee4fc78ce5c60ab6975f59_translated.bpmn and saved to ./output/processed_Regressnahme_8acc7092c0ee4fc78ce5c60ab6975f59_translated.bpmn.txt
# Processed Regressnahme_8b91ae6ec245484e80077e102ca01529_translated.bpmn and saved to ./output/processed_Regressnahme_8b91ae6ec245484e80077e102ca01529_translated.bpmn.txt
# Processed Regressnahme_8bc74bb1df5c472c9ded212cf7dcb808_translated.bpmn and saved to ./output/processed_Regressnahme_8bc74bb1df5c472c9ded212cf7dcb808_translated.bpmn.txt
# Processed Regressnahme_8c4a90dc80ed4accbaad3f1f58b2bd05_translated.bpmn and saved to ./output/processed_Regressnahme_8c4a90dc80ed4accbaad3f1f58b2bd05_translated.bpmn.txt
# Processed Regressnahme_8c93c5611d8845edb94ed69f0e87ea62_translated.bpmn and saved to ./output/processed_Regressnahme_8c93c5611d8845edb94ed69f0e87ea62_translated.bpmn.txt
# Processed Regressnahme_8de23e47565c4850bbd1d393c75542a0_translated.bpmn and saved to ./output/processed_Regressnahme_8de23e47565c4850bbd1d393c75542a0_translated.bpmn.txt
# Processed Regressnahme_8f994c8766324cb7928c2db16ffd746c_translated.bpmn and saved to ./output/processed_Regressnahme_8f994c8766324cb7928c2db16ffd746c_translated.bpmn.txt
# Processed regressnahme_8fa505692030466da02efa9cb79dac7c_translated.bpmn and saved to ./output/processed_regressnahme_8fa505692030466da02efa9cb79dac7c_translated.bpmn.txt
# Processed Regressnahme_8fd5376535df48618e341c8c3c035349_translated.bpmn and saved to ./output/processed_Regressnahme_8fd5376535df48618e341c8c3c035349_translated.bpmn.txt
# Processed Regressnahme_91f10ad3aa8640efad5712f9642c7ebd_translated.bpmn and saved to ./output/processed_Regressnahme_91f10ad3aa8640efad5712f9642c7ebd_translated.bpmn.txt
# Processed Regressnahme_92c23f00fa8c413fba8cb60bc9c95cfb_translated.bpmn and saved to ./output/processed_Regressnahme_92c23f00fa8c413fba8cb60bc9c95cfb_translated.bpmn.txt
# Processed Regressnahme_92c515fe220a435aa974ebc8b30d7f9c_translated.bpmn and saved to ./output/processed_Regressnahme_92c515fe220a435aa974ebc8b30d7f9c_translated.bpmn.txt
# Processed Regressnahme_92e7b720af5e436fb6baec4f2c7c68f7_translated.bpmn and saved to ./output/processed_Regressnahme_92e7b720af5e436fb6baec4f2c7c68f7_translated.bpmn.txt
# Processed Regressnahme_92f69806c1984d27b69f2bf30c0ec74a_translated.bpmn and saved to ./output/processed_Regressnahme_92f69806c1984d27b69f2bf30c0ec74a_translated.bpmn.txt
# Processed Regressnahme_9301eb8234414bc096665d5622e308c0_translated.bpmn and saved to ./output/processed_Regressnahme_9301eb8234414bc096665d5622e308c0_translated.bpmn.txt
# Processed Regressnahme_941f051b7fcd4ebfa5f317d81a57ffa4_translated.bpmn and saved to ./output/processed_Regressnahme_941f051b7fcd4ebfa5f317d81a57ffa4_translated.bpmn.txt
# Processed Regressnahme_989ac8d8d694498ab3a07737ea21a1a2_translated.bpmn and saved to ./output/processed_Regressnahme_989ac8d8d694498ab3a07737ea21a1a2_translated.bpmn.txt
# Processed Regressnahme_992053fe8c724494bf58bd7ce6ea06da_translated.bpmn and saved to ./output/processed_Regressnahme_992053fe8c724494bf58bd7ce6ea06da_translated.bpmn.txt
# Processed Regressnahme_99b88aad9d0841098ee0d47a541fa49f_translated.bpmn and saved to ./output/processed_Regressnahme_99b88aad9d0841098ee0d47a541fa49f_translated.bpmn.txt
# Processed Regressnahme_9d7bfa7661a4478a875bca396216914c_translated.bpmn and saved to ./output/processed_Regressnahme_9d7bfa7661a4478a875bca396216914c_translated.bpmn.txt
# Processed Regressnahme_9e8338273a984bd2b130d3b35e7474f7_translated.bpmn and saved to ./output/processed_Regressnahme_9e8338273a984bd2b130d3b35e7474f7_translated.bpmn.txt
# Processed Regressnahme_9edeee6a546a4aa4a8cddcf5686a272b_translated.bpmn and saved to ./output/processed_Regressnahme_9edeee6a546a4aa4a8cddcf5686a272b_translated.bpmn.txt
# Processed Regressnahme_a1b94fa090d14b599211ad7d0cdb662a_translated.bpmn and saved to ./output/processed_Regressnahme_a1b94fa090d14b599211ad7d0cdb662a_translated.bpmn.txt
# Processed Regressnahme_a1c7564052d94a9587df7ac29e02963d_translated.bpmn and saved to ./output/processed_Regressnahme_a1c7564052d94a9587df7ac29e02963d_translated.bpmn.txt
# Processed Regressnahme_a2da397578064a41b4bfb168b40a0a10_translated.bpmn and saved to ./output/processed_Regressnahme_a2da397578064a41b4bfb168b40a0a10_translated.bpmn.txt
# Processed Regressnahme_a314907eba384d1585994e2f180489a1_translated.bpmn and saved to ./output/processed_Regressnahme_a314907eba384d1585994e2f180489a1_translated.bpmn.txt
# Processed Regressnahme_a529dde4503249d19905112d7cfbb4fa_translated.bpmn and saved to ./output/processed_Regressnahme_a529dde4503249d19905112d7cfbb4fa_translated.bpmn.txt
# Processed Regressnahme_a9046ccdfd0e436dbc5d86dee4972d9b_translated.bpmn and saved to ./output/processed_Regressnahme_a9046ccdfd0e436dbc5d86dee4972d9b_translated.bpmn.txt
# Processed regressnahme_aa7f20ce30024394a7388a024fe56f0f_translated.bpmn and saved to ./output/processed_regressnahme_aa7f20ce30024394a7388a024fe56f0f_translated.bpmn.txt
# Processed Regressnahme_ab4c0d55da7b444dbd9d430819a0faa2_translated.bpmn and saved to ./output/processed_Regressnahme_ab4c0d55da7b444dbd9d430819a0faa2_translated.bpmn.txt
# Processed Regressnahme_ab8d22ab6a4f49099a0b95dc4434aa91_translated.bpmn and saved to ./output/processed_Regressnahme_ab8d22ab6a4f49099a0b95dc4434aa91_translated.bpmn.txt
# Processed Regressnahme_aca05ae00eb244a186de1d7827bbc909_translated.bpmn and saved to ./output/processed_Regressnahme_aca05ae00eb244a186de1d7827bbc909_translated.bpmn.txt
# Processed Regressnahme_aea5a8d9810449a285762cf369b85f24_translated.bpmn and saved to ./output/processed_Regressnahme_aea5a8d9810449a285762cf369b85f24_translated.bpmn.txt
# Processed Regressnahme_af02f10eecbe4560b4575bb53d3fdb8c_translated.bpmn and saved to ./output/processed_Regressnahme_af02f10eecbe4560b4575bb53d3fdb8c_translated.bpmn.txt
# Processed Regressnahme_aktuell_2dc7aefd4ef84ada90723008dcca7d14_translated.bpmn and saved to ./output/processed_Regressnahme_aktuell_2dc7aefd4ef84ada90723008dcca7d14_translated.bpmn.txt
# Processed Regressnahme_b1f03b9495a74ee389cef77ef44875b8_translated.bpmn and saved to ./output/processed_Regressnahme_b1f03b9495a74ee389cef77ef44875b8_translated.bpmn.txt
# Processed Regressnahme_b255d3ebc606439a8b56fe75ac36e5e0_translated.bpmn and saved to ./output/processed_Regressnahme_b255d3ebc606439a8b56fe75ac36e5e0_translated.bpmn.txt
# Processed Regressnahme_b44b2c9743bc416ab77a643fc64d57f1_translated.bpmn and saved to ./output/processed_Regressnahme_b44b2c9743bc416ab77a643fc64d57f1_translated.bpmn.txt
# Processed regressnahme_b551dd2fdb2c48bf8449690372f52940_translated.bpmn and saved to ./output/processed_regressnahme_b551dd2fdb2c48bf8449690372f52940_translated.bpmn.txt
# Processed Regressnahme_b63e23c62f76479197f4a10af873ac3e_translated.bpmn and saved to ./output/processed_Regressnahme_b63e23c62f76479197f4a10af873ac3e_translated.bpmn.txt
# Processed Regressnahme_b656c2f577aa4d669a66c1b933d4ef73_translated.bpmn and saved to ./output/processed_Regressnahme_b656c2f577aa4d669a66c1b933d4ef73_translated.bpmn.txt
# Processed Regressnahme_b774ce58ae674c21b2b744cb713877d1_translated.bpmn and saved to ./output/processed_Regressnahme_b774ce58ae674c21b2b744cb713877d1_translated.bpmn.txt
# Processed Regressnahme_ba5d4117421246108852b3ca6c5de2b8_translated.bpmn and saved to ./output/processed_Regressnahme_ba5d4117421246108852b3ca6c5de2b8_translated.bpmn.txt
# Processed Regressnahme_bb46010f920f44a99cdd0eb8a29fa1f7_translated.bpmn and saved to ./output/processed_Regressnahme_bb46010f920f44a99cdd0eb8a29fa1f7_translated.bpmn.txt
# Processed Regressnahme_bb4b30cd94df43c0bc5345ad1e63835b_translated.bpmn and saved to ./output/processed_Regressnahme_bb4b30cd94df43c0bc5345ad1e63835b_translated.bpmn.txt
# Processed Regressnahme_bbc292fb12a141a08398bc9e77c13dbc_translated.bpmn and saved to ./output/processed_Regressnahme_bbc292fb12a141a08398bc9e77c13dbc_translated.bpmn.txt
# Processed Regressnahme_bd8b979295c2485a88c7139eae795a30_translated.bpmn and saved to ./output/processed_Regressnahme_bd8b979295c2485a88c7139eae795a30_translated.bpmn.txt
# Processed Regressnahme_bd92179d3642470aadd89dcd77a329fc_translated.bpmn and saved to ./output/processed_Regressnahme_bd92179d3642470aadd89dcd77a329fc_translated.bpmn.txt
# Processed Regressnahme_bee170a922d74eeb81e9a8c042ac3ee7_translated.bpmn and saved to ./output/processed_Regressnahme_bee170a922d74eeb81e9a8c042ac3ee7_translated.bpmn.txt
# Processed Regressnahme_c0ae0bc902c04546a19fabaaa93492cf_translated.bpmn and saved to ./output/processed_Regressnahme_c0ae0bc902c04546a19fabaaa93492cf_translated.bpmn.txt
# Processed Regressnahme_c1098524d4184234bfe0abf27bcc4bf4_translated.bpmn and saved to ./output/processed_Regressnahme_c1098524d4184234bfe0abf27bcc4bf4_translated.bpmn.txt
# Processed Regressnahme_c189303d518b4c42a2d5ac52637edf88_translated.bpmn and saved to ./output/processed_Regressnahme_c189303d518b4c42a2d5ac52637edf88_translated.bpmn.txt
# Processed Regressnahme_c400c2b3134d440fad61b318dfb67e98_translated.bpmn and saved to ./output/processed_Regressnahme_c400c2b3134d440fad61b318dfb67e98_translated.bpmn.txt
# Processed Regressnahme_c46410738e254beeb51fa78c15eb28cf_translated.bpmn and saved to ./output/processed_Regressnahme_c46410738e254beeb51fa78c15eb28cf_translated.bpmn.txt
# Processed Regressnahme_c4879a4a4f9f47ea8d436aec0253f51d_translated.bpmn and saved to ./output/processed_Regressnahme_c4879a4a4f9f47ea8d436aec0253f51d_translated.bpmn.txt
# Processed regressnahme_c5da182906c544c5a911b4abcf61f5ba_translated.bpmn and saved to ./output/processed_regressnahme_c5da182906c544c5a911b4abcf61f5ba_translated.bpmn.txt
# Processed Regressnahme_c67c8e29f969492cac39615590a68882_translated.bpmn and saved to ./output/processed_Regressnahme_c67c8e29f969492cac39615590a68882_translated.bpmn.txt
# Processed Regressnahme_c874b64626d749ada6637e1f9bdd8018_translated.bpmn and saved to ./output/processed_Regressnahme_c874b64626d749ada6637e1f9bdd8018_translated.bpmn.txt
# Processed regressnahme_ca37cb40cc4f41169c868aa1b4702674_translated.bpmn and saved to ./output/processed_regressnahme_ca37cb40cc4f41169c868aa1b4702674_translated.bpmn.txt
# ...
# Processed _bung_7_-_Schufa_Scoring__Kopie__e6fe40afdd4f4756bcc9e23dcf925470_translated.bpmn and saved to ./output/processed__bung_7_-_Schufa_Scoring__Kopie__e6fe40afdd4f4756bcc9e23dcf925470_translated.bpmn.txt
# Processed _bung_7_-_Schufa_Scoring__Kopie___Kopie__1598df467495425b92dcb6de2b0e9fa9_translated.bpmn and saved to ./output/processed__bung_7_-_Schufa_Scoring__Kopie___Kopie__1598df467495425b92dcb6de2b0e9fa9_translated.bpmn.txt
# Processed _bung_7_035825236917461491c9b1b50a0a9339_translated.bpmn and saved to ./output/processed__bung_7_035825236917461491c9b1b50a0a9339_translated.bpmn.txt
# Processed _bung_7_074b3fdb10414e0cad91197140d492a1_translated.bpmn and saved to ./output/processed__bung_7_074b3fdb10414e0cad91197140d492a1_translated.bpmn.txt
# Processed _bung_7_0ad77b59ee654b0ba9282f76cdccb24f_translated.bpmn and saved to ./output/processed__bung_7_0ad77b59ee654b0ba9282f76cdccb24f_translated.bpmn.txt
# Processed _bung_7_16270c5001094096a2443f46631e2da0_translated.bpmn and saved to ./output/processed__bung_7_16270c5001094096a2443f46631e2da0_translated.bpmn.txt
# Processed _bung_7_16409f330b914e7c949e6972e3ca666f_translated.bpmn and saved to ./output/processed__bung_7_16409f330b914e7c949e6972e3ca666f_translated.bpmn.txt
# Processed _bung_7_25affa2f11ed4f43b75e5cb9e0bc15a9_translated.bpmn and saved to ./output/processed__bung_7_25affa2f11ed4f43b75e5cb9e0bc15a9_translated.bpmn.txt
# Processed _bung_7_490d277a0651484e8e83b419a55c68a5_translated.bpmn and saved to ./output/processed__bung_7_490d277a0651484e8e83b419a55c68a5_translated.bpmn.txt
# Processed _bung_7_4b0674c170b64d3dbbd09944646a2e00_translated.bpmn and saved to ./output/processed__bung_7_4b0674c170b64d3dbbd09944646a2e00_translated.bpmn.txt
# Processed _bung_7_56b8f24cff4a43e29b274684dcfe11c3_translated.bpmn and saved to ./output/processed__bung_7_56b8f24cff4a43e29b274684dcfe11c3_translated.bpmn.txt
# Processed _bung_7_5a3341b60b3b494e897124dce9942fd3_translated.bpmn and saved to ./output/processed__bung_7_5a3341b60b3b494e897124dce9942fd3_translated.bpmn.txt
# Processed _bung_7_8b9339bcf360484fba390b80bf2b84ab_translated.bpmn and saved to ./output/processed__bung_7_8b9339bcf360484fba390b80bf2b84ab_translated.bpmn.txt
# Processed _bung_7_8e84a57d9d1148f88a8a2aaeea352815_translated.bpmn and saved to ./output/processed__bung_7_8e84a57d9d1148f88a8a2aaeea352815_translated.bpmn.txt
# Processed _bung_7_9663f5b5376249dabaf4ffa66b3c1955_translated.bpmn and saved to ./output/processed__bung_7_9663f5b5376249dabaf4ffa66b3c1955_translated.bpmn.txt
# Processed _bung_7_a1c251d92de14bd39ee616d0c535d8fc_translated.bpmn and saved to ./output/processed__bung_7_a1c251d92de14bd39ee616d0c535d8fc_translated.bpmn.txt
# Processed _bung_7_b5442f228e5747a385b9dee71d95dd36_translated.bpmn and saved to ./output/processed__bung_7_b5442f228e5747a385b9dee71d95dd36_translated.bpmn.txt
# Processed _bung_7_b58860dff66a4454a0a37cedf802432b_translated.bpmn and saved to ./output/processed__bung_7_b58860dff66a4454a0a37cedf802432b_translated.bpmn.txt
# Processed _bung_7_c6b461ff01d344e0bafc1323df2dcfbb_translated.bpmn and saved to ./output/processed__bung_7_c6b461ff01d344e0bafc1323df2dcfbb_translated.bpmn.txt
# Processed _bung_7_c9e90f823f494561b26208c8ba01ae35_translated.bpmn and saved to ./output/processed__bung_7_c9e90f823f494561b26208c8ba01ae35_translated.bpmn.txt
# Processed _bung_7_d5a7e549d8734cb7ad2b1d24b3efc314_translated.bpmn and saved to ./output/processed__bung_7_d5a7e549d8734cb7ad2b1d24b3efc314_translated.bpmn.txt
# Processed _bung_7_d94938ab5f91419d86073307a0194f50_translated.bpmn and saved to ./output/processed__bung_7_d94938ab5f91419d86073307a0194f50_translated.bpmn.txt
# Processed _bung_7_db01412d50794d8fa61c4845d07c0764_translated.bpmn and saved to ./output/processed__bung_7_db01412d50794d8fa61c4845d07c0764_translated.bpmn.txt
# Processed _bung_7_dc7c8330417744ca9713cf01970379a7_translated.bpmn and saved to ./output/processed__bung_7_dc7c8330417744ca9713cf01970379a7_translated.bpmn.txt
# Processed _bung_7_df674ef648ee48e6bc672ce95a25d6e6_translated.bpmn and saved to ./output/processed__bung_7_df674ef648ee48e6bc672ce95a25d6e6_translated.bpmn.txt
# Processed _bung_7_e0fee6ac7bf04f7fac2a4a16dbe60177_translated.bpmn and saved to ./output/processed__bung_7_e0fee6ac7bf04f7fac2a4a16dbe60177_translated.bpmn.txt
# Processed _bung_7_e555ba5c59664d0999c8dd9a066c42d6_translated.bpmn and saved to ./output/processed__bung_7_e555ba5c59664d0999c8dd9a066c42d6_translated.bpmn.txt
# Processed _bung_7_e962199a0fb747f2ba638c72bec96402_translated.bpmn and saved to ./output/processed__bung_7_e962199a0fb747f2ba638c72bec96402_translated.bpmn.txt
# Processed _bung_7_eeade0aaaacd437c93d41510692646a7_translated.bpmn and saved to ./output/processed__bung_7_eeade0aaaacd437c93d41510692646a7_translated.bpmn.txt
# Processed _bung_7_fbed1ee65a904bc88db7724e330f5b55_translated.bpmn and saved to ./output/processed__bung_7_fbed1ee65a904bc88db7724e330f5b55_translated.bpmn.txt
# Processed _bung_7_Schufaergebnis_4d43b95825864ee0b4f4e9e005d9dae1_translated.bpmn and saved to ./output/processed__bung_7_Schufaergebnis_4d43b95825864ee0b4f4e9e005d9dae1_translated.bpmn.txt
# Processed _bung_7_Schufascoring_06abf9d90c4c473087edfff40e064360_translated.bpmn and saved to ./output/processed__bung_7_Schufascoring_06abf9d90c4c473087edfff40e064360_translated.bpmn.txt
# Processed _bung_7_Schufascoring_f3410dba8df7477d9acc76508bfdc3b2_translated.bpmn and saved to ./output/processed__bung_7_Schufascoring_f3410dba8df7477d9acc76508bfdc3b2_translated.bpmn.txt
# Processed _bung_7_Schufascoring_f6e0ceedb4f9437da6e6022ee5ce3e38_translated.bpmn and saved to ./output/processed__bung_7_Schufascoring_f6e0ceedb4f9437da6e6022ee5ce3e38_translated.bpmn.txt
# Processed _bung_7_Schufa_Scoring_86001f147d674b92b208f00fe942e348_translated.bpmn and saved to ./output/processed__bung_7_Schufa_Scoring_86001f147d674b92b208f00fe942e348_translated.bpmn.txt
# Processed _bung_7_Ulrike_a262614ac40f4509a21e4cd8decffe8d_translated.bpmn and saved to ./output/processed__bung_7_Ulrike_a262614ac40f4509a21e4cd8decffe8d_translated.bpmn.txt
# Processed _bung_7__Schufascoring_38dd71fd26814b7cb2b0135d9c3a60f9_translated.bpmn and saved to ./output/processed__bung_7__Schufascoring_38dd71fd26814b7cb2b0135d9c3a60f9_translated.bpmn.txt
# Processed _bung_7__Schufascoring_7bdda9daf77e4039add74021f35cbc4f_translated.bpmn and saved to ./output/processed__bung_7__Schufascoring_7bdda9daf77e4039add74021f35cbc4f_translated.bpmn.txt
# Processed _bung_7__Schufa_Scoring_e49dcdba10914d62a0e89540bcb49eb9_translated.bpmn and saved to ./output/processed__bung_7__Schufa_Scoring_e49dcdba10914d62a0e89540bcb49eb9_translated.bpmn.txt
# Processed _bung_8_-_SB_Restaurant_1468bec385da4e5fb53a3a45b9846524_translated.bpmn and saved to ./output/processed__bung_8_-_SB_Restaurant_1468bec385da4e5fb53a3a45b9846524_translated.bpmn.txt
# Processed _bung_8_-_Selbstbedienungrestaurant_e452257c77a0407d986749a62528dc25_translated.bpmn and saved to ./output/processed__bung_8_-_Selbstbedienungrestaurant_e452257c77a0407d986749a62528dc25_translated.bpmn.txt
# Processed _bung_8_-_Selbstbedienungsrestaurant_14d82513f7d24f54b9ad5974ec09b965_translated.bpmn and saved to ./output/processed__bung_8_-_Selbstbedienungsrestaurant_14d82513f7d24f54b9ad5974ec09b965_translated.bpmn.txt
# Processed _bung_8_-_Selbstbedienungsrestaurant_2938ef73d95245aa845e51fa2ec504ac_translated.bpmn and saved to ./output/processed__bung_8_-_Selbstbedienungsrestaurant_2938ef73d95245aa845e51fa2ec504ac_translated.bpmn.txt
# Processed _bung_8_-_Selbstbedienungsrestaurant_3020286a161743219cad5371d7acd8f0_translated.bpmn and saved to ./output/processed__bung_8_-_Selbstbedienungsrestaurant_3020286a161743219cad5371d7acd8f0_translated.bpmn.txt
# Processed _bung_8_-_Selbstbedienungsrestaurant_4aca705e26c14d26ac4fe6ac20fdfc55_translated.bpmn and saved to ./output/processed__bung_8_-_Selbstbedienungsrestaurant_4aca705e26c14d26ac4fe6ac20fdfc55_translated.bpmn.txt
# Processed _bung_8_-_Selbstbedienungsrestaurant_52371f3fa99b4a07a68ac0a9e8ea86de_translated.bpmn and saved to ./output/processed__bung_8_-_Selbstbedienungsrestaurant_52371f3fa99b4a07a68ac0a9e8ea86de_translated.bpmn.txt
# Processed _bung_8_-_Selbstbedienungsrestaurant_893e26afd47c439e8f2ebdae9fd53320_translated.bpmn and saved to ./output/processed__bung_8_-_Selbstbedienungsrestaurant_893e26afd47c439e8f2ebdae9fd53320_translated.bpmn.txt
# Processed _bung_8_-_Selbstbedienungsrestaurant_dd92b684a7da4214add224dd1a6570d4_translated.bpmn and saved to ./output/processed__bung_8_-_Selbstbedienungsrestaurant_dd92b684a7da4214add224dd1a6570d4_translated.bpmn.txt
# Processed _bung_8_-_Selbstbedienungsrestaurant_e1e68d2525f14f75982cab42039d3617_translated.bpmn and saved to ./output/processed__bung_8_-_Selbstbedienungsrestaurant_e1e68d2525f14f75982cab42039d3617_translated.bpmn.txt
# Processed _bung_8_058d26585ee846dd99b458506ec1a015_translated.bpmn and saved to ./output/processed__bung_8_058d26585ee846dd99b458506ec1a015_translated.bpmn.txt
# Processed _bung_8_0dedf1e185b04c15a841463d0811e8e9_translated.bpmn and saved to ./output/processed__bung_8_0dedf1e185b04c15a841463d0811e8e9_translated.bpmn.txt
# Processed _bung_8_1e0b9ead91ca4aafb6c7835b97c253bf_translated.bpmn and saved to ./output/processed__bung_8_1e0b9ead91ca4aafb6c7835b97c253bf_translated.bpmn.txt
# Processed _bung_8_1f6322dd9d4144f895b0efd9879c17a6_translated.bpmn and saved to ./output/processed__bung_8_1f6322dd9d4144f895b0efd9879c17a6_translated.bpmn.txt
# Processed _bung_8_22e21e16ec8742c187d7537a310c887b_translated.bpmn and saved to ./output/processed__bung_8_22e21e16ec8742c187d7537a310c887b_translated.bpmn.txt
# Processed _bung_8_2bdbe557179240b58541d384f4ab066b_translated.bpmn and saved to ./output/processed__bung_8_2bdbe557179240b58541d384f4ab066b_translated.bpmn.txt
# Processed _bung_8_2ebec0cdc4674da0aaf12bae81a5c0bf_translated.bpmn and saved to ./output/processed__bung_8_2ebec0cdc4674da0aaf12bae81a5c0bf_translated.bpmn.txt
# Processed _bung_8_3a25d188c47f4a1a818e65f32686b61c_translated.bpmn and saved to ./output/processed__bung_8_3a25d188c47f4a1a818e65f32686b61c_translated.bpmn.txt
# Processed _bung_8_3dff9e1733ff4620897ea9bab359c2be_translated.bpmn and saved to ./output/processed__bung_8_3dff9e1733ff4620897ea9bab359c2be_translated.bpmn.txt
# Processed _bung_8_3e4280c9086143289696f01975b6f4de_translated.bpmn and saved to ./output/processed__bung_8_3e4280c9086143289696f01975b6f4de_translated.bpmn.txt
# Processed _bung_8_497b49e7252b4c69ba240575bf5df739_translated.bpmn and saved to ./output/processed__bung_8_497b49e7252b4c69ba240575bf5df739_translated.bpmn.txt
# Processed _bung_8_4f4d76b5bd764ee8ac16339dedd094cb_translated.bpmn and saved to ./output/processed__bung_8_4f4d76b5bd764ee8ac16339dedd094cb_translated.bpmn.txt
# Processed _bung_8_580d49d9c6964f46880b04e77803ca6e_translated.bpmn and saved to ./output/processed__bung_8_580d49d9c6964f46880b04e77803ca6e_translated.bpmn.txt
# Processed _bung_8_696e9d17d89149c68b555b5ba030c349_translated.bpmn and saved to ./output/processed__bung_8_696e9d17d89149c68b555b5ba030c349_translated.bpmn.txt
# Processed _bung_8_6e68a6629bb3494fbd4d54916bd54d67_translated.bpmn and saved to ./output/processed__bung_8_6e68a6629bb3494fbd4d54916bd54d67_translated.bpmn.txt
# Processed _bung_8_711ff0a17ec64a8ab29e6537ce06ce04_translated.bpmn and saved to ./output/processed__bung_8_711ff0a17ec64a8ab29e6537ce06ce04_translated.bpmn.txt
# Processed _bung_8_7150520baa594ed29b28593f7d1718c1_translated.bpmn and saved to ./output/processed__bung_8_7150520baa594ed29b28593f7d1718c1_translated.bpmn.txt
# Processed _bung_8_84934bc3ed2b442d835068ffae3dd4cd_translated.bpmn and saved to ./output/processed__bung_8_84934bc3ed2b442d835068ffae3dd4cd_translated.bpmn.txt
# Processed _bung_8_9dbced47fddd49c4961ded6989ee6726_translated.bpmn and saved to ./output/processed__bung_8_9dbced47fddd49c4961ded6989ee6726_translated.bpmn.txt
# Processed _bung_8_c5e9a703e1cf4db89e749a16c5b4ec11_translated.bpmn and saved to ./output/processed__bung_8_c5e9a703e1cf4db89e749a16c5b4ec11_translated.bpmn.txt
# Processed _bung_8_cd7449383cd142879e2daf43296ab3e4_translated.bpmn and saved to ./output/processed__bung_8_cd7449383cd142879e2daf43296ab3e4_translated.bpmn.txt
# Processed _bung_8_d31e7cf4ea7a4b5a9fa842f2e070bdb2_translated.bpmn and saved to ./output/processed__bung_8_d31e7cf4ea7a4b5a9fa842f2e070bdb2_translated.bpmn.txt
# Processed _bung_8_d41dff4c228f49da8135a614dd01ff28_translated.bpmn and saved to ./output/processed__bung_8_d41dff4c228f49da8135a614dd01ff28_translated.bpmn.txt
# Processed _bung_8_d65b959d947f434b8c5b8d7d45ac3d04_translated.bpmn and saved to ./output/processed__bung_8_d65b959d947f434b8c5b8d7d45ac3d04_translated.bpmn.txt
# Processed _bung_8_dd841572df304ca3aefea9588a186681_translated.bpmn and saved to ./output/processed__bung_8_dd841572df304ca3aefea9588a186681_translated.bpmn.txt
# Processed _bung_8_dfa7879b3df54d728625919a98761ee8_translated.bpmn and saved to ./output/processed__bung_8_dfa7879b3df54d728625919a98761ee8_translated.bpmn.txt
# Processed _bung_8_e31167b7e1bd448b8b6ba3b398657e87_translated.bpmn and saved to ./output/processed__bung_8_e31167b7e1bd448b8b6ba3b398657e87_translated.bpmn.txt
# Processed _bung_8_f1287a5dce284f6e82bd044775b5ca15_translated.bpmn and saved to ./output/processed__bung_8_f1287a5dce284f6e82bd044775b5ca15_translated.bpmn.txt
# Processed _bung_8_f69ce80db7e84a528fcc746c269d9869_translated.bpmn and saved to ./output/processed__bung_8_f69ce80db7e84a528fcc746c269d9869_translated.bpmn.txt
# Processed _bung_8_Selbstbedienungsrestaurant_177e93738df14c3b83adbb7e3fb8c594_translated.bpmn and saved to ./output/processed__bung_8_Selbstbedienungsrestaurant_177e93738df14c3b83adbb7e3fb8c594_translated.bpmn.txt
# Processed _bung_8_Selbstbedienungsrestaurant_47053ccdbce7419b8e7eec5972917689_translated.bpmn and saved to ./output/processed__bung_8_Selbstbedienungsrestaurant_47053ccdbce7419b8e7eec5972917689_translated.bpmn.txt
# Processed _bung_8_Selbstbedienungsrestaurant_6d6fd70aedc244c896bf09129c037f0a_translated.bpmn and saved to ./output/processed__bung_8_Selbstbedienungsrestaurant_6d6fd70aedc244c896bf09129c037f0a_translated.bpmn.txt
# Processed _bung_8_Selbstbedienungsrestaurant_db1bbd00568f4a7bb9d79a08af5d65c5_translated.bpmn and saved to ./output/processed__bung_8_Selbstbedienungsrestaurant_db1bbd00568f4a7bb9d79a08af5d65c5_translated.bpmn.txt
# Processed _bung_8__Kopie__efa9d63ac34545eb84bbb78d4e81ba82_translated.bpmn and saved to ./output/processed__bung_8__Kopie__efa9d63ac34545eb84bbb78d4e81ba82_translated.bpmn.txt
# Processed _bung_8__Selbstbedienungsrestaurant_037ed0a513714834820b7231f549de9a_translated.bpmn and saved to ./output/processed__bung_8__Selbstbedienungsrestaurant_037ed0a513714834820b7231f549de9a_translated.bpmn.txt
# Processed _bung_8__Selbstbedienungsrestaurant_2bc80e680c9c4af0a64ec226fc7aab7c_translated.bpmn and saved to ./output/processed__bung_8__Selbstbedienungsrestaurant_2bc80e680c9c4af0a64ec226fc7aab7c_translated.bpmn.txt
# Processed _bung_8__Selbstbedienungsrestaurant_959d1c8b88ac4002905105b37302d959_translated.bpmn and saved to ./output/processed__bung_8__Selbstbedienungsrestaurant_959d1c8b88ac4002905105b37302d959_translated.bpmn.txt
# Processed _bung_e79259d74bc048d2beb230e4ee921521_translated.bpmn and saved to ./output/processed__bung_e79259d74bc048d2beb230e4ee921521_translated.bpmn.txt
# Processed _bung_Schufascoring_24ffb9e9d0cd4e66a690bf5e7c8e6209_translated.bpmn and saved to ./output/processed__bung_Schufascoring_24ffb9e9d0cd4e66a690bf5e7c8e6209_translated.bpmn.txt
# Processed _Schufascoring_6468db0ef3424c2f9da6fe6f1859d71d_translated.bpmn and saved to ./output/processed__Schufascoring_6468db0ef3424c2f9da6fe6f1859d71d_translated.bpmn.txt
# Processed __bung7_f6f5a07e1aed4c648c452ab5ace0a870_translated.bpmn and saved to ./output/processed___bung7_f6f5a07e1aed4c648c452ab5ace0a870_translated.bpmn.txt
# Processed __bung_1_920e781ac88741f18ff6143eacad5539_translated.bpmn and saved to ./output/processed___bung_1_920e781ac88741f18ff6143eacad5539_translated.bpmn.txt
